# %% [markdown]
# ## Course : Advanced Certificate Program in Machine Learning & Cloud
#
# ## Module : Capstone Project - User Demographics Prediction using Telecom dataset
#
# ## Authors : Sanjana Mantri

# %% [markdown]
# # Objective

# %% [markdown]
# A data preparation was carried out earlier in HIVE and prepared data wasstored in the S3 bucket.
# Three data files were created and stored in S3
#
# *   non_events.csv
# *   events.csv
# *   appdata.csv
#
# In this part of the exercise the following activities will be carried out
#
# <B> This notebook file is meant for performing the following
#
# * TASK 1 -  Reading Data
# * TASK 2 -  Cleaning Data
# * TASK 3 -  Basic EDA and Visualizations
#
# Other tasks will be performed in seperate notebooks
# </B>
#
# ## TASK 1 - Reading Data
#
# * Reading data from S3 in EC2
# * Reading CSVs in data frame
#
# ## TASK 2 -  Cleaning Data
#
# * Null checks
# * Imputations
# * Handling Categorical, Binary and Numerical columns
# * Check for high cardinality columns
# * Handling categorical columns having large values
#
# ## TASK 3 - Basic EDA and Visualization, Feature Engineering Ideas
#
# *  Plot appropriate graphs which represent the distribution of Age and gender in the Dataset [Univariate]
# *  Boxplot analysis for gender and Age [Bivariate]
# *  Plot percentage of device_ids with and without event data
# *  Graph representing the distribution of events on different days of a week
# *  Graph representing the distribution of events per hour [ For one-week data]
# *  The difference in the distribution of events per hour for Male and Females?  [Show the difference using an appropriate chart
#    for one-week data]
# *  Is there any difference in the distribution of Events for different Age Groups over different days of the week? [Consider
#    the age groups as 0-24, 25-32, 33-45, 46+]
# *  Stacked bar chart for top 10 mobile brands across male and female consumers
# *  Chart representing ten frequent applications and their respective male and female percentage
# *  Top 10  Mobile Phone Brand  by age groups [Consider the age groups as 0-24, 25-32, 33-45, 46+]

# %%
# import libraries
# 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # **TASK 1 - Reading Data**

# %% [markdown]
# ## 1.1 Download data from s3 bucket

# %%
# download non_events.csv from s3 bucket
# 
# !aws s3 cp s3://capstone-sanjanameghna/non_events.csv .
# Out:
# download: s3://capstone-sanjanameghna/non_events.csv to ./non_events.csv

# %%
# download events.csv from s3 bucket
#
# !aws s3 cp s3://capstone-sanjanameghna/events.csv .
# Out:
# download: s3://capstone-sanjanameghna/events.csv to ./events.csv

# %%
# download appdata.csv from s3 bucket
#
# !aws s3 cp s3://capstone-sanjanameghna/appdata.csv .
# Out:
# download: s3://capstone-sanjanameghna/appdata.csv to ./appdata.csv

# %% [markdown]
# ## 1.2  Reading CSVs into pandas dataframe

# %% [markdown]
# #### 1.2.1 Load Non Events dataset into pandas dataframe

# %%
# Read non_events dataset into pandas dataframe
# 
dfnev = pd.read_csv('non_events.csv', encoding='utf-8')

# %%
# Verify dataset shape
#
dfnev.shape
# Out:
# (74840, 6)

# %%
# Verify column types
# 
dfnev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74840 entries, 0 to 74839
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   non_event_data_external.device_id     74840 non-null  int64
#  1   non_event_data_external.phone_brand   74840 non-null  object
#  2   non_event_data_external.device_model  74840 non-null  object
#  3   non_event_data_external.gender        74840 non-null  object
#  4   non_event_data_external.age           74840 non-null  int64
#  5   non_event_data_external.group_train   74840 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.4+ MB

# %%
# Rename column headings
# 
dfnev.rename(columns={
                'non_event_data_external.device_id' : 'device_id',
                'non_event_data_external.phone_brand' : 'phone_brand',
                'non_event_data_external.device_model' : 'device_model',
                'non_event_data_external.gender' : 'gender',
                'non_event_data_external.age' : 'age',
                'non_event_data_external.group_train' : 'group_train'
                }, inplace = True
            )

# %%
# Display first 5 records
#

dfnev.head(5)
# Out:
#              device_id phone_brand device_model gender  age group_train
# 0  1845358998536310000       meitu            2      F   25      F25-32
# 1  3126957642374570000       meitu            2      M   27      M25-32
# 2  6005031767544890000       meitu            2      F   30      F25-32
# 3  7862170554164260000       meitu            2      F   22       F0-24
# 4 -1463646610464190000       meitu            2      F   24       F0-24

# %%
# Checking binary column 'gender'
#
dfnev['gender'].value_counts(dropna=False)
# Out:
# M    48035
# F    26805
# Name: gender, dtype: int64

# %%
# Checking ordinal column group_train
# 
dfnev['group_train'].value_counts(dropna=False)
# Out:
# M25-32    19901
# M32+      16316
# M0-24     11818
# F25-32    10741
# F32+       9780
# F0-24      6284
# Name: group_train, dtype: int64

# %%
dfnev[dfnev.age > 32]
# Out:
#                  device_id phone_brand    device_model gender  age group_train
# 11     3850960887861590000       meitu               2      M   34        M32+
# 15     1323187103995530000       meitu               2      M   34        M32+
# 16     7163627422543500000       meitu               2      F   54        F32+
# 17     1312435195549850000       meitu               2      F   37        F32+
# 19    -5656200008905250000       youmi               3      F   41        F32+
# ...                    ...         ...             ...    ...  ...         ...
# 74824  2033746267945220000        asus       ZenFone 5      F   37        F32+
# 74828 -5986444829585820000        asus       ZenFone 5      M   33        M32+
# 74833 -5816542174733950000        asus     ZenFone Max      F   33        F32+
# 74835 -5876986818792990000        asus     ZenFone Max      M   35        M32+
# 74839  6705691319720020000        asus  ZenFone Selfie      M   33        M32+
#
# [26096 rows x 6 columns]

# %%
# Checking categorical column device_model
# 
dfnev['device_model'].value_counts(dropna=False)
# Out:
# xnote                 3016
# MI 3                  2304
# MI 2S                 2138
# Galaxy Note 3         2070
# MI 4                  1914
#                       ...
# BM003                    1
# Galaxy Tab A 8.0         1
# Galaxy Tab 2 P5100       1
# 8712S                    1
# X6666                    1
# Name: device_model, Length: 1438, dtype: int64

# %%
# Checking categorical column phone_brand
# 
dfnev['phone_brand'].value_counts(dropna=False)
# Out:
# Xiaomi     17337
# samsung    13706
# Huawei     13001
# OPPO        5802
# vivo        5658
#            ...
# fs             1
# ZOYE           1
# mole           1
# Ctyon          1
# pner           1
# Name: phone_brand, Length: 97, dtype: int64

# %% [markdown]
# #### 1.2.1 Load Events dataset into pandas dataframe

# %%
total_rows = dfnev.shape[0]
nullDataSeries = dfnev.isnull().sum()
nullDataSeries = nullDataSeries[nullDataSeries > 0].sort_values(ascending = False).apply(lambda x: (x/total_rows)*100 )
nullDataSeries
# Out:
# Series([], dtype: int64)

# %%
# read events dataset into pandas dataframe
# 
dfev = pd.read_csv('events.csv', encoding='utf-8')

# %%
# verify dataset shape
#
dfev.shape
# Out:
# (1215598, 8)

# %%
# verify column types
# 
dfev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215598 entries, 0 to 1215597
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   events_train_external.device_id    1215598 non-null  int64
#  1   events_train_external.event_id     1215598 non-null  int64
#  2   events_train_external.event_time   1215598 non-null  object
#  3   events_train_external.latitude     1215598 non-null  float64
#  4   events_train_external.longitude    1215598 non-null  float64
#  5   events_train_external.gender       1215598 non-null  object
#  6   events_train_external.age          1215598 non-null  int64
#  7   events_train_external.group_train  1215598 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 74.2+ MB

# %%
# rename column headings
# 
dfev.rename(columns={
                'events_train_external.device_id' : 'device_id',
                'events_train_external.event_id' : 'event_id',
                'events_train_external.event_time' : 'event_time',
                'events_train_external.latitude' : 'latitude',
                'events_train_external.longitude' : 'longitude',
                'events_train_external.gender' : 'gender',
                'events_train_external.age' : 'age',
                'events_train_external.group_train' : 'group_train'
                }, inplace = True
            )

# %%
# display first 5 records
# 
dfev.head(5)
# Out:
#              device_id  event_id           event_time  latitude  longitude  \
# 0  4676982795249940000   2958924  2016-05-01 22:03:46    113.24      22.85
# 1  4782582047729160000   2958931  2016-05-01 22:24:09    114.47      38.03
# 2  2181284491650730000   2958933  2016-05-01 22:24:44    125.66      43.02
# 3  4221762657972680000   2958935  2016-05-01 22:40:47    115.19      24.07
# 4 -2990318111507320000   2958938  2016-05-01 21:59:08      0.00       0.00
#
#   gender  age group_train
# 0      M   52        M32+
# 1      M   36        M32+
# 2      M   28      M25-32
# 3      F   19       F0-24
# 4      F   32      F25-32

# %%
# Checking binary column 'gender'
#
dfev['gender'].value_counts(dropna=False)
# Out:
# M    864306
# F    351292
# Name: gender, dtype: int64

# %%
# Checking ordinal column group_train
# 
dfev['group_train'].value_counts(dropna=False)
# Out:
# M32+      387589
# M25-32    346988
# F32+      163410
# F25-32    132532
# M0-24     129729
# F0-24      55350
# Name: group_train, dtype: int64

# %%
# Checking zero values count in columns latitude & longitude 
#
dfev.loc[(~((dfev.latitude > 0) & (dfev.longitude > 0)))]
# Out:
#                    device_id  event_id           event_time  latitude  \
# 4       -2990318111507320000   2958938  2016-05-01 21:59:08       0.0
# 10       5838192187148920000   2958950  2016-05-01 22:12:46       0.0
# 12       4737717997133900000   2958954  2016-05-01 22:30:38       0.0
# 17       9219842210460030000   2958969  2016-05-01 22:41:54       0.0
# 38      -3082540067142970000   2959019  2016-05-01 22:00:11       0.0
# ...                      ...       ...                  ...       ...
# 1215583  2865406474920660000   2958881  2016-05-07 21:13:19       0.0
# 1215587 -3700868433721280000   2958896  2016-05-01 22:28:16       0.0
# 1215589 -4968824142785510000   2958899  2016-05-01 22:52:18       0.0
# 1215593  1727035210770580000   2958907  2016-05-01 22:36:31       0.0
# 1215595 -2740470823835500000   2958919  2016-05-01 22:17:10       0.0
#
#          longitude gender  age group_train
# 4              0.0      F   32      F25-32
# 10             0.0      M   28      M25-32
# 12             0.0      M   33        M32+
# 17             0.0      F   29      F25-32
# 38             0.0      M   73        M32+
# ...            ...    ...  ...         ...
# 1215583        0.0      M   40        M32+
# 1215587        0.0      F   26      F25-32
# 1215589        0.0      F   30      F25-32
# 1215593        0.0      F   23       F0-24
# 1215595        0.0      F   26      F25-32
#
# [356821 rows x 8 columns]

# %% [markdown]
# #### 1.2.3 Load Appdata dataset into pandas dataframe

# %%
# read appdata dataset into pandas dataframe
# To avoid the error 'EOF inside string starting at row....', caused by a string that contained within it a single quote mark,
# the option quoting=csv.QUOTE_NONE is used
import csv
dfapp = pd.read_csv('appdata.csv',quoting=csv.QUOTE_NONE, encoding='utf-8')

# %%
# verify dataset shape
#
dfapp.shape
# Out:
# (55614759, 6)

# %%
# Verify column types
# 
dfapp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55614759 entries, 0 to 55614758
# Data columns (total 6 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   app_data_external.event_id      int64
#  1   app_data_external.app_id        int64
#  2   app_data_external.is_installed  float64
#  3   app_data_external.is_active     float64
#  4   app_data_external.label_id      float64
#  5   app_data_external.category      object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.5+ GB

# %%
# rename column headings
#
dfapp.rename(columns={
                'app_data_external.event_id' : 'event_id',
                'app_data_external.app_id' : 'app_id',
                'app_data_external.is_installed' : 'is_installed',
                'app_data_external.is_active' : 'is_active',
                'app_data_external.label_id' : 'label_id',
                'app_data_external.category' : 'category'
                }, inplace = True
            )

# %%
# display first 5 records
# 
dfapp.head(5)
# Out:
#    event_id               app_id  is_installed  is_active  label_id  \
# 0   2960967  8557198901083791098           1.0        1.0     548.0
# 1   2960967  8557198901083791098           1.0        1.0     204.0
# 2   2960967  8557198901083791098           1.0        1.0     172.0
# 3   2960967  8557198901083791098           1.0        1.0     223.0
# 4   2960967  8557198901083791098           1.0        1.0     206.0
#
#                category
# 0          Industry tag
# 1        sports and gym
# 2                    IM
# 3  convenience services
# 4               Medical

# %%
total_rows = dfapp.shape[0]
nullDataSeriesApp = dfapp.isnull().sum()
nullDataSeriesApp = nullDataSeriesApp[nullDataSeriesApp > 0].sort_values(ascending = False).apply(lambda x: (x/total_rows)*100 )
nullDataSeriesApp
# Out:
# category        0.000002
# label_id        0.000002
# is_active       0.000002
# is_installed    0.000002
# dtype: float64

# %% [markdown]
# ## TASK 2 - Cleaning Data

# %% [markdown]
# ### 2.1 Cleaning non-events dataset

# %%
dfnev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74840 entries, 0 to 74839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   device_id     74840 non-null  int64
#  1   phone_brand   74840 non-null  object
#  2   device_model  74840 non-null  object
#  3   gender        74840 non-null  object
#  4   age           74840 non-null  int64
#  5   group_train   74840 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.4+ MB

# %%
# device_model column contains junk characters, need to clean up the junk characters
# 
dfnev.device_model.unique().tolist()
# Out:
# ['2',
#  '3',
#  '201',
#  '1100',
#  '1105',
#  '1107',
#  '3000',
#  '3005',
#  '3007',
#  '5217',
#  '5219',
#  '5261',
#  '5263',
#  '5310',
#  '5311',
#  '5316',
#  '5360',
#  '5832',
#  '5872',
#  '5876',
#  '5879',
#  '5890',
#  '5891',
#  '5892',
#  '5930',
#  '5950',
#  '5951',
#  '5956',
#  '6607',
#  '7060',
#  '7061',
#  '7105',
#  '7230',
#  '7231',
#  '7235',
#  '7236',
#  '7251',
#  '7260',
#  '7268',
#  '7269',
#  '7270',
#  '7275',
#  '7295',
#  '7296',
#  '7320',
#  '7372',
#  '7605',
#  '8017',
#  '8021',
#  '8029',
#  '8056',
#  '8060',
#  '8070',
#  '8079',
#  '8085',
#  '8089',
#  '8105',
#  '8122',
#  '8150',
#  '8185',
#  '8190',
#  '8195',
#  '8295',
#  '8702',
#  '8705',
#  '8707',
#  '8712',
#  '8713',
#  '8715',
#  '8717',
#  '8720',
#  '8721',
#  '8722',
#  '8729',
#  '8732',
#  '8736',
#  '8750',
#  '8800',
#  '9150',
#  '9180',
#  ':UOOGOUT1',
#  '2016GalAxyA5',
#  '2016GalAxyA7',
#  '2016GalAxyA9',
#  '210R',
#  '3S',
#  '5200S',
#  '5216D',
#  '5216s',
#  '5218S',
#  '5263S',
#  '5313S',
#  '5860S',
#  '5891Q',
#  '603e',
#  '606w',
#  '608t',
#  '7060S',
#  '7270-W00',
#  '7295+',
#  '7295A123',
#  '7295C',
#  '7296S',
#  '7298D',
#  '7620l',
#  '795+',
#  '7i',
#  '8017-T00',
#  '802d',
#  '802w',
#  '8076D',
#  '8085n',
#  '8085q',
#  '8150D',
#  '8190Q',
#  '8198T',
#  '8295c',
#  '8295M',
#  '8702D',
#  '8712S',
#  '8720L',
#  '8730L',
#  '9190l',
#  '9300-M9',
#  '9976A',
#  '9976D',
#  'a1234',
#  'a1234C',
#  'bigv23',
#  'z123',
#  'a0901',
#  '45rt2',
#  '45rggt2',
#  'cv1plus',
#  '900tr2',
#  'cv1',
#  '900tr212',
#  '900tr2123',
#  'a1900tr212',
#  'å¤§è§‚4',
#  'å¤§è§‚é“‚é¡¿',
#  'epaiNote',
#  'gv11',
#  'å¤©é‰´W808',
#  'å¤©é‰´W900',
#  'å¤©é‰´W900S',
#  'å€¾åŸŽL3',
#  'å€¾åŸŽL3C',
#  'å°\x8fæ˜Ÿæ˜Ÿ',
#  'å°\x8fç±³4C',
#  'xnote11',
#  'å°\x8fç«\xa0é±¼',
#  'å°\x8fè‹¹æžœ',
#  'å°\x8fè¾£æ¤’ 3',
#  'å°\x8fè¾£æ¤’ 4',
#  'å°\x8fè¾£æ¤’ 5',
#  'å°\x8fè¾£æ¤’ 6',
#  'å°\x8fè¾£æ¤’ 7',
#  'å°\x8fè¾£æ¤’ M2',
#  'å°\x8fè¾£æ¤’ M3',
#  'å°\x8fè¾£æ¤’ X3',
#  'å°\x8fè¾£æ¤’5 Pro',
#  'å°\x8fè¾£æ¤’S1',
#  'å°\x8fè¾£æ¤’X4',
#  'å°\x8fé²œ2',
#  'å°\x8fé²œ3',
#  'å\x9dšæžœæ‰‹æœº',
#  'å¾®å®¢',
#  'A1',
#  'ä¹ˆä¹ˆå“’',
#  'ä¹ˆä¹ˆå“’3N',
#  'ä¹ˆä¹ˆå“’3S',
#  'ä¹\x90æª¬3',
#  'ä¹\x90æª¬K3',
#  'ä¹\x90æª¬K3 Note',
#  'ä¹\x90æª¬K31',
#  'ä¹\x90æª¬X3',
#  'ä¹\x90çŽ©',
#  'A100',
#  'A1020',
#  'A11',
#  'A199',
#  'A208t',
#  'a218t',
#  'A238t',
#  'A2580',
#  'A269i',
#  'A278t',
#  'A2800d',
#  'A2860',
#  'A288t',
#  'A298t',
#  'A3',
#  'A30',
#  'A3000-H',
#  'A300t',
#  'A308t',
#  'A31',
#  'A318t',
#  'A320t',
#  'A328t',
#  'A33',
#  'A3300-T',
#  'A330e',
#  'A3500',
#  'A355e',
#  'A356',
#  'A358t',
#  'A3600d',
#  'A360e',
#  'A360t',
#  'A366t',
#  'A368t',
#  'A369',
#  'A376',
#  'A378t',
#  'A3800d',
#  'A380e',
#  'A380t',
#  'A385e',
#  'A388t',
#  'A3890',
#  'A390',
#  'A3900',
#  'A390t',
#  'A395e',
#  'A396',
#  'A398t',
#  'A398t+',
#  'A399',
#  'A5',
#  'A505e',
#  'A51',
#  'A516',
#  'A51kc',
#  'A520',
#  'A53',
#  'A560',
#  'A580',
#  'A5800-D',
#  'A586',
#  'A590',
#  'A60+',
#  'A606',
#  'A628t',
#  'A630',
#  'A630e',
#  'A630t',
#  'A65',
#  'A656',
#  'A658t',
#  'A660',
#  'A670t',
#  'A678t',
#  'A680',
#  'A6800',
#  'A688t',
#  'A690',
#  'A698t',
#  'A7',
#  'A706',
#  'A708t',
#  'A7-30',
#  'A750',
#  'A750e',
#  'A760',
#  'A766',
#  'A768t',
#  'A770e',
#  'A780e',
#  'A785e',
#  'A788t',
#  'A789',
#  'A798t',
#  'A800',
#  'A805e',
#  'A820',
#  'A820e',
#  'A820t',
#  'A828t',
#  'A830',
#  'A850',
#  'A8-50',
#  'A850+',
#  'A858t',
#  'A860e',
#  'A880',
#  'A889',
#  'A890e',
#  'æ¸´æœ›HD',
#  'æ˜¥é›·HD',
#  'æ˜Ÿæ˜Ÿ1å\x8f·',
#  'æ˜Ÿæ˜Ÿ2å\x8f·',
#  'æ—‹å½±90w',
#  'æ—¶å°šæ‰‹æœº',
#  'æ——èˆ°ç‰ˆ',
#  'Ascend D1',
#  'Ascend D2',
#  'Ascend G6',
#  'Ascend G7',
#  'Ascend G700',
#  'Ascend G700T',
#  'Ascend GX1',
#  'Ascend P1',
#  'Ascend P6',
#  'Ascend P7',
#  'Ascend P8',
#  'Axonå¤©æœº',
#  'Axonå¤©æœº Max',
#  'AxonMini',
#  'B199',
#  'B8080-F',
#  'B9388',
#  'BF A500',
#  'BF T18',
#  'BF T18 Plus',
#  'Blade A1',
#  'Blade C',
#  'Blade S6',
#  'Blade S6 Lux',
#  'BM001',
#  'BM002',
#  'BM003',
#  'Butterfly',
#  'Butterfly s',
#  'ç‚«å½±S+',
#  'ç•…äº«5',
#  'ç•…äº«5S',
#  'ç\x81«æ˜Ÿä¸€å\x8f·',
#  'ç\x81«æ˜Ÿä¸€å\x8f·æŽ¢ç´¢ç‰ˆ',
#  'ç\x81µæ„ŸXL',
#  'C03',
#  'C230w',
#  'C630Lw',
#  'C666t',
#  'C730Lw',
#  'C8812',
#  'C8812+',
#  'C8813',
#  'C8813D',
#  'C8813DQ',
#  'C8813Q',
#  'C8815',
#  'C8816',
#  'C8816D',
#  'C8817E',
#  'C8817L',
#  'C8818',
#  'C986t',
#  'C986t+',
#  'x1',
#  'x11S',
#  'x12',
#  'x12A',
#  'x13',
#  'xnote',
#  'xnote2',
#  'xnote3',
#  'xnotea11',
#  'zt_121',
#  'çº¢è¾£æ¤’',
#  'çº¢è¾£æ¤’ X1',
#  'çº¢è¾£æ¤’ä»»æ€§ç‰ˆ Plus',
#  'çº¢è¾£æ¤’Note',
#  'çº¢è¾£æ¤’Note3',
#  'çº¢è¾£æ¤’NX Plus',
#  'çº¢è¾£æ¤’XM',
#  'çº½æ‰£',
#  'Compaq 7',
#  'ç™¾åˆ©ä¸° W2',
#  'CYM1',
#  'D1',
#  'D2-M',
#  'D330',
#  'D350',
#  'D360',
#  'D500',
#  'D516w',
#  'D520',
#  'D557',
#  'D800',
#  'Defy+',
#  'Desire 310',
#  'Desire 5088',
#  'Desire 510',
#  'Desire 609d',
#  'Desire 610t',
#  'Desire 616',
#  'Desire 626',
#  'Desire 7088',
#  'Desire 816',
#  'Desire 816x',
#  'Desire 820',
#  'Desire 820 Mini',
#  'Desire 826',
#  'Desire D316d',
#  'Desire D516d',
#  'Desire D516t',
#  'Desire HD',
#  'Desire S',
#  'Desire V',
#  'Doeasy E700',
#  'DROID RAZR',
#  'DROID RAZR M',
#  'è¿œèˆª3',
#  'é”‹å°š',
#  'é”‹å°š2',
#  'é”‹å°šAir',
#  'é”‹å°šMax',
#  'é”‹å°šmini',
#  'é”‹å°šPro',
#  'é\xad”é•œ X5',
#  'é›·éœ†æˆ˜æœº',
#  'é¢†ä¸–æ——èˆ°3',
#  'é£Žå\x8dŽ3',
#  'é£žé©¬',
#  'é£žé©¬2 Plus',
#  'é»„é‡‘æ–—å£«A8',
#  'é»„é‡‘æ–—å£«é\x9d’æ˜¥ç‰ˆ',
#  'é»„é‡‘æ–—å£«Note8',
#  'é»„é‡‘æ–—å£«S8ç•…çŽ©ç‰ˆ',
#  'è¶…çº§æ‰‹æœº1',
#  'è¶…çº§æ‰‹æœº1 Pro',
#  'ihv1',
#  'è¶…çº§æ‰‹æœºMax',
#  'è¶…çº§æ‰‹æœºMax Pro',
#  'é\xad…è“\x9d',
#  'é\xad…è“\x9d2',
#  'é\xad…è“\x9dmetal',
#  'menote1',
#  'menote1 2',
#  'menote13',
#  'é†‰äº«',
#  'é‡‘é’¢',
#  'é\x9d’æ˜¥ç‰ˆ',
#  'é\x9d’æ¼¾3',
#  'è\x81”æƒ³é»„é‡‘æ–—å£«S8',
#  'è\x81”æƒ³VIBE X2',
#  'è\x8d£è€€+',
#  'è\x8d£è€€3C',
#  'è\x8d£è€€3Cç•…çŽ©ç‰ˆ',
#  'è\x8d£è€€3X',
#  'è\x8d£è€€3Xç•…çŽ©ç‰ˆ',
#  'è\x8d£è€€4A',
#  'hu1',
#  'hu1 Plus',
#  'hu1 plus',
#  'è\x8d£è€€7',
#  'è\x8d£è€€7i',
#  'è\x8d£è€€å¹³æ\x9d¿T1-823L',
#  'è\x8d£è€€ç•…çŽ©4',
#  'è\x8d£è€€ç•…çŽ©4C',
#  'è\x8d£è€€ç•…çŽ©4Cè¿\x90åŠ¨ç‰ˆ',
#  'è\x8d£è€€ç•…çŽ©4X',
#  'è\x8d£è€€ç•…çŽ©5',
#  'è\x8d£è€€ç•…çŽ©5X',
#  'è\x8d£è€€ç•…çŽ©å¹³æ\x9d¿T1',
#  'è\x8d£è€€U8860',
#  'è\x8d£è€€V8',
#  'è\x8d£è€€X2',
#  'E1',
#  'E100T',
#  'E1T',
#  'E260-T',
#  'E3',
#  'E5',
#  'E50-T',
#  'E6',
#  'E600M',
#  'E601M',
#  'E602M',
#  'E602T',
#  'E613M',
#  'E619',
#  'E619+',
#  'E620M',
#  'E621T',
#  'E622M',
#  'E625T',
#  'E6T',
#  'E7',
#  'E70-T',
#  'E8',
#  'E820',
#  'E912S',
#  'E99',
#  'EG929',
#  'EG936D',
#  'EG939',
#  'EG966',
#  'EG970',
#  'EG971',
#  'EG978',
#  'EG980',
#  'ELIFE E3T',
#  'ELIFE E6 mini',
#  'ELIFE E7 Mini',
#  'ELIFE S5.5',
#  'éº¦èŠ’3',
#  'éº¦èŠ’3S',
#  'éº¦èŠ’4',
#  'EV5',
#  'EVO 3D X515m',
#  'F103',
#  'F103S',
#  'F105',
#  'F2',
#  'F301',
#  'F303',
#  'F320L',
#  'F8909',
#  'Find',
#  'Find 3',
#  'Find 5',
#  'Find 7',
#  'G11',
#  'G2',
#  'G3',
#  'G309T',
#  'G3588V',
#  'G3609',
#  'G3818',
#  'G3819D',
#  'G4',
#  'G510',
#  'G520-0000',
#  'G520-5000',
#  'G520-T10',
#  'G521',
#  'G525',
#  'G606',
#  'G610C',
#  'G610M',
#  'G610S',
#  'G610T',
#  'G615-U10',
#  'G616-L076',
#  'G620-L72',
#  'G620-L75',
#  'G628',
#  'G629',
#  'G630',
#  'G660-L075',
#  'G6-C00',
#  'G6-U00',
#  'G7 Plus',
#  'G716',
#  'G717C',
#  'G718C',
#  'G7200',
#  'G730-C00',
#  'G730-L075',
#  'G730-T00',
#  'G730-U00',
#  'G730-U30',
#  'G750-T20',
#  'G9',
#  'Galaxy A3',
#  'Galaxy A5',
#  'Galaxy A7',
#  'Galaxy A8',
#  'Galaxy Ace',
#  'Galaxy Ace 2',
#  'Galaxy Ace 3',
#  'Galaxy Ace 4',
#  'Galaxy Ace Dear',
#  'Galaxy Ace DUOS',
#  'Galaxy Ace Plus',
#  'Galaxy Alpha',
#  'Galaxy Core',
#  'Galaxy Core 2',
#  'Galaxy Core 4G',
#  'Galaxy Core Advance',
#  'Galaxy Core Lite',
#  'Galaxy Core Max',
#  'Galaxy Core Mini',
#  'Galaxy Core Prime',
#  'Galaxy E7',
#  'Galaxy Fame',
#  'Galaxy Gio',
#  'Galaxy Golden',
#  'Galaxy Grand',
#  'Galaxy Grand 2',
#  'Galaxy Grand 2 LTE',
#  'Galaxy Grand DUOS',
#  'Galaxy Grand Neo Plus',
#  'Galaxy Grand Prime',
#  'Galaxy Infinite',
#  'Galaxy J',
#  'Galaxy J3',
#  'Galaxy J5',
#  'Galaxy J7',
#  'Galaxy K Zoom',
#  'Galaxy Mega 2',
#  'Galaxy Mega 5.8',
#  'Galaxy Mega 6.3',
#  'Galaxy Mega Plus',
#  'Galaxy Mini',
#  'Galaxy Nexus',
#  'Galaxy Note',
#  'Galaxy Note 10.1',
#  'Galaxy Note 10.1 2014 Edition P601',
#  'Galaxy Note 10.1 N8010',
#  'Galaxy Note 2',
#  'Galaxy Note 3',
#  'Galaxy Note 3 Lite',
#  'Galaxy Note 4',
#  'Galaxy Note 5',
#  'Galaxy Note 8.0',
#  'Galaxy Note Edge',
#  'Galaxy On5',
#  'Galaxy On7',
#  'Galaxy Premier',
#  'Galaxy R',
#  'Galaxy S',
#  'Galaxy S Advance',
#  'Galaxy S DUOS',
#  'Galaxy S DUOS 2',
#  'Galaxy S L',
#  'Galaxy S Plus',
#  'Galaxy S2',
#  'Galaxy S2 Epic 4G Touch',
#  'Galaxy S2 HD LTE E120S',
#  'Galaxy S2 Plus',
#  'Galaxy S3',
#  'Galaxy S3 Mini',
#  'Galaxy S3 Neo+',
#  'Galaxy S4',
#  'Galaxy S4 Mini',
#  'Galaxy S4 Zoom',
#  'Galaxy S5',
#  'Galaxy S5 Plus',
#  'Galaxy S6',
#  'Galaxy S6 Edge',
#  'Galaxy S6 Edge+',
#  'Galaxy S7',
#  'Galaxy S7 Edge',
#  'Galaxy Style DUOS',
#  'Galaxy Tab 2 P3100',
#  'Galaxy Tab 2 P5100',
#  'Galaxy Tab 2 P5110',
#  'Galaxy Tab 3 10.1',
#  'Galaxy Tab 3 7.0',
#  'Galaxy Tab 3 8.0',
#  'Galaxy Tab 3 Lite T110',
#  'Galaxy Tab 3 Lite T111',
#  'Galaxy Tab 4 T231',
#  'Galaxy Tab 4 T331C',
#  'Galaxy Tab 7.0 Plus',
#  'Galaxy Tab A 8.0',
#  'Galaxy Tab P1000',
#  'Galaxy Tab P6800',
#  'Galaxy Tab Pro T321',
#  'Galaxy Tab S T705',
#  'Galaxy Tab S T705C',
#  'Galaxy Tab S T805C',
#  'Galaxy Trend',
#  'Galaxy Trend 2',
#  'Galaxy Trend 3',
#  'Galaxy Trend DUOS',
#  'Galaxy Trend DUOS 2',
#  'Galaxy W',
#  'Galaxy Win',
#  'Galaxy Win Pro',
#  'Galaxy Y',
#  'Gigaset ME',
#  'GN100',
#  'GN105',
#  'GN106',
#  'GN108',
#  'GN128',
#  'GN135',
#  'GN137',
#  'GN139',
#  'GN150',
#  'GN151',
#  'GN152',
#  'GN180',
#  'GN305',
#  'GN5001S',
#  'GN5002',
#  'GN700T',
#  'GN700W',
#  'GN705',
#  'GN705T',
#  'GN706L',
#  'GN708T',
#  'GN708W',
#  'GN715',
#  'GN800',
#  'GN810',
#  'GN878',
#  'GN9002',
#  'GN9004',
#  'Grand Memo',
#  'Grand Memo 2',
#  'Grand S 2',
#  'Grand X',
#  'Grand X Quad',
#  'GT7',
#  'GT-I8160',
#  'H1',
#  'H1S',
#  'H2',
#  'H3',
#  'H6',
#  'HN3-U01',
#  'Hol-U10',
#  'HS-U971',
#  'HS-U978',
#  'HT-I857',
#  'HT-I860',
#  'i1',
#  'I6',
#  'i600',
#  'I630M',
#  'I630T',
#  'I632T',
#  'I635T',
#  'I639T',
#  'I699I',
#  'I7',
#  'I779',
#  'I8250',
#  'I8258',
#  'I8268',
#  'I9050',
#  'I9118',
#  'I95',
#  'IdeaTab 2109A',
#  'IdeaTab A1000-T',
#  'IdeaTab A1010-T',
#  'IdeaTab A2207A-H',
#  'IdeaTab A5000-E',
#  'idol X',
#  'idol3',
#  'IPH8',
#  'iPh-800',
#  'iSuper S1',
#  'iSuper S2',
#  'IUSAI US15',
#  'IVO 6600',
#  'IVO 6622',
#  'IVO 6655',
#  'IVO 6666',
#  'IVO 6688',
#  'IVO 8800',
#  'ivvi å°\x8féª¨Pro',
#  'ivvi å°\x8fi',
#  'ivvi K1 mini',
#  'ivvi S6',
#  'J320T',
#  'J636D+',
#  'J738M',
#  'JX8166',
#  'K012',
#  'K1',
#  'K35',
#  'K68w',
#  'K80',
#  'K860',
#  'K860i',
#  'K88L',
#  'K900',
#  'KDOOR X5-Y12',
#  'Kindle Fire HDX 7.0',
#  'King 7',
#  'King 7s',
#  'L1',
#  'L1 mini',
#  'L100',
#  'L108',
#  'L128',
#  'L168',
#  'L22',
#  'L3',
#  'L5 mini',
#  'L5 Plus',
#  'L5Pro',
#  'L7',
#  'L70',
#  'L8',
#  'L810',
#  'L82',
#  'L820',
#  'L823',
#  'L855',
#  'L9',
#  'L920',
#  'L930i',
#  'LT01',
#  'LT02',
#  'LT416',
#  'LT988',
#  'M030',
#  'M031',
#  'M032',
#  'M1',
#  'M10-M',
#  'M15',
#  'M2',
#  'M201S',
#  'M20-M',
#  'M20-T',
#  'M210',
#  'M228-M51',
#  'M3',
#  'M310',
#  'm310',
#  'M311',
#  'M3S',
#  'M4',
#  'M4S',
#  'M5',
#  'M5 Plus',
#  'M512',
#  'M560',
#  'M6',
#  'M601',
#  'M6-M7',
#  'M701',
#  'M8',
#  'M811',
#  'M812C',
#  'M8St',
#  'M9',
#  'Mate',
#  'Mate 2',
#  'Mate 7',
#  'mate7es2',
#  'Mate 8',
#  'Mate S',
#  'MAX3',
#  'MC002',
#  'ME371MG',
#  'ME7510KG',
#  'MediaPad 10 FHD',
#  'MediaPad 10 Link',
#  'MediaPad 10 Link+?',
#  'MediaPad 7 Vogue',
#  'MediaPad M1',
#  'MediaPad M2-801W',
#  'MediaPad M2-803L',
#  'memo 5S',
#  'meTalV123',
#  'MI 1',
#  'MI 1S',
#  'MI 2',
#  'MI 2A',
#  'MI 2C',
#  'MI 2S',
#  'MI 3',
#  'MI 4',
#  'MI 4S',
#  'MI 5',
#  'MI One C1',
#  'MI One Plus',
#  'MI pad',
#  'MI pad 2',
#  'MK260',
#  'MM1101',
#  'MM1104',
#  'MOMO9',
#  'Mos1',
#  'Moto G',
#  'Moto Turbo',
#  'Moto X',
#  'Moto X 3',
#  'Moto X Pro',
#  'Moto X Style',
#  'Moto12X12',
#  'MT1-U06',
#  'MT2-C00',
#  'MUSE',
#  'MX2',
#  'MX3',
#  'MX4',
#  'MX4 Pro',
#  'MX5',
#  'myone123',
#  'N1',
#  'N1 max',
#  'N1 Mini',
#  'N1T',
#  'N1W',
#  'N1-Y',
#  'N2',
#  'N3',
#  'N798',
#  'N818',
#  'N821',
#  'N828',
#  'N880E',
#  'N880F',
#  'N881F',
#  'N909',
#  'N910C',
#  'N910U',
#  'N919',
#  'N986',
#  'Nexus 4',
#  'Nexus 5',
#  'Nexus 5X',
#  'Nexus 6P',
#  'Nexus 7',
#  'Nexus S',
#  'notev123',
#  'OKA31',
#  'One',
#  'One A9',
#  'One E8',
#  'One E9',
#  'One M8',
#  'One M8 Eye',
#  'One M9',
#  'One M9+',
#  'One M9e',
#  'One max',
#  'One ME',
#  'One S',
#  'One X',
#  'One X9',
#  'ono',
#  'Optimus G',
#  'Optimus G Pro',
#  'Optimus G Pro 2',
#  'Optimus LTE',
#  'P1',
#  'P1c58',
#  'P2',
#  'P3',
#  'P301M',
#  'P302C',
#  'P305',
#  'P306C',
#  'P308L',
#  'P316L',
#  'P318L',
#  'P331M',
#  'P332U',
#  'P335M',
#  'P360W',
#  'P500M',
#  'P501M',
#  'P502U',
#  'P51',
#  'P518L',
#  'P520L',
#  'P596',
#  'P6',
#  'P688L',
#  'P70',
#  'P700',
#  'P700i',
#  'P705',
#  'P770',
#  'P780',
#  'P8',
#  'P8 Lite',
#  'P880',
#  'P8max',
#  'P9',
#  'P9 Plus',
#  'P970',
#  'PHAB Plus',
#  'PRO5',
#  'Q201T',
#  'Q301C',
#  'Q302C',
#  'Q3C',
#  'Q501T',
#  'Q501U',
#  'Q503U',
#  'Q505T',
#  'Q507T',
#  'Q509T',
#  'Q519T',
#  'Q7',
#  'Q701C',
#  'Q705U',
#  'Q801L',
#  'Q802T',
#  'Q805T',
#  'R1',
#  'R1C',
#  'R1S',
#  'R2010',
#  'R2017',
#  'R3',
#  'R5',
#  'R5s plus',
#  'R6007',
#  'R7',
#  'R7 Plus',
#  'R7s',
#  'R8000',
#  'R801',
#  'R805',
#  'R807',
#  'R809T',
#  ...]

# %%
# Define function to cleanup junk characters from given column
# 
import re
def strip_character(dataCol):
    dataCol = dataCol.strip()              # remove leadning and trailing spaces
    r = re.compile(r'[^a-zA-Z !@#$%&*_+-=|\:";<>,./()[\]{}\']')    
    return r.sub('', dataCol)

# %%
# invoke strip_character() function to clean up the junk characters.
# 
dfnev['device_model'] = dfnev['device_model'].apply(strip_character)

# %%
dfnev.device_model.unique().tolist()
# Out:
# ['2',
#  '3',
#  '201',
#  '1100',
#  '1105',
#  '1107',
#  '3000',
#  '3005',
#  '3007',
#  '5217',
#  '5219',
#  '5261',
#  '5263',
#  '5310',
#  '5311',
#  '5316',
#  '5360',
#  '5832',
#  '5872',
#  '5876',
#  '5879',
#  '5890',
#  '5891',
#  '5892',
#  '5930',
#  '5950',
#  '5951',
#  '5956',
#  '6607',
#  '7060',
#  '7061',
#  '7105',
#  '7230',
#  '7231',
#  '7235',
#  '7236',
#  '7251',
#  '7260',
#  '7268',
#  '7269',
#  '7270',
#  '7275',
#  '7295',
#  '7296',
#  '7320',
#  '7372',
#  '7605',
#  '8017',
#  '8021',
#  '8029',
#  '8056',
#  '8060',
#  '8070',
#  '8079',
#  '8085',
#  '8089',
#  '8105',
#  '8122',
#  '8150',
#  '8185',
#  '8190',
#  '8195',
#  '8295',
#  '8702',
#  '8705',
#  '8707',
#  '8712',
#  '8713',
#  '8715',
#  '8717',
#  '8720',
#  '8721',
#  '8722',
#  '8729',
#  '8732',
#  '8736',
#  '8750',
#  '8800',
#  '9150',
#  '9180',
#  ':UOOGOUT1',
#  '2016GalAxyA5',
#  '2016GalAxyA7',
#  '2016GalAxyA9',
#  '210R',
#  '3S',
#  '5200S',
#  '5216D',
#  '5216s',
#  '5218S',
#  '5263S',
#  '5313S',
#  '5860S',
#  '5891Q',
#  '603e',
#  '606w',
#  '608t',
#  '7060S',
#  '7270-W00',
#  '7295+',
#  '7295A123',
#  '7295C',
#  '7296S',
#  '7298D',
#  '7620l',
#  '795+',
#  '7i',
#  '8017-T00',
#  '802d',
#  '802w',
#  '8076D',
#  '8085n',
#  '8085q',
#  '8150D',
#  '8190Q',
#  '8198T',
#  '8295c',
#  '8295M',
#  '8702D',
#  '8712S',
#  '8720L',
#  '8730L',
#  '9190l',
#  '9300-M9',
#  '9976A',
#  '9976D',
#  'a1234',
#  'a1234C',
#  'bigv23',
#  'z123',
#  'a0901',
#  '45rt2',
#  '45rggt2',
#  'cv1plus',
#  '900tr2',
#  'cv1',
#  '900tr212',
#  '900tr2123',
#  'a1900tr212',
#  '4',
#  '',
#  'epaiNote',
#  'gv11',
#  'W808',
#  'W900',
#  'W900S',
#  'L3',
#  'L3C',
#  '4C',
#  'xnote11',
#  ' 3',
#  ' 4',
#  ' 5',
#  ' 6',
#  ' 7',
#  ' M2',
#  ' M3',
#  ' X3',
#  '5 Pro',
#  'S1',
#  'X4',
#  'A1',
#  '3N',
#  'K3',
#  'K3 Note',
#  'K31',
#  'X3',
#  'A100',
#  'A1020',
#  'A11',
#  'A199',
#  'A208t',
#  'a218t',
#  'A238t',
#  'A2580',
#  'A269i',
#  'A278t',
#  'A2800d',
#  'A2860',
#  'A288t',
#  'A298t',
#  'A3',
#  'A30',
#  'A3000-H',
#  'A300t',
#  'A308t',
#  'A31',
#  'A318t',
#  'A320t',
#  'A328t',
#  'A33',
#  'A3300-T',
#  'A330e',
#  'A3500',
#  'A355e',
#  'A356',
#  'A358t',
#  'A3600d',
#  'A360e',
#  'A360t',
#  'A366t',
#  'A368t',
#  'A369',
#  'A376',
#  'A378t',
#  'A3800d',
#  'A380e',
#  'A380t',
#  'A385e',
#  'A388t',
#  'A3890',
#  'A390',
#  'A3900',
#  'A390t',
#  'A395e',
#  'A396',
#  'A398t',
#  'A398t+',
#  'A399',
#  'A5',
#  'A505e',
#  'A51',
#  'A516',
#  'A51kc',
#  'A520',
#  'A53',
#  'A560',
#  'A580',
#  'A5800-D',
#  'A586',
#  'A590',
#  'A60+',
#  'A606',
#  'A628t',
#  'A630',
#  'A630e',
#  'A630t',
#  'A65',
#  'A656',
#  'A658t',
#  'A660',
#  'A670t',
#  'A678t',
#  'A680',
#  'A6800',
#  'A688t',
#  'A690',
#  'A698t',
#  'A7',
#  'A706',
#  'A708t',
#  'A7-30',
#  'A750',
#  'A750e',
#  'A760',
#  'A766',
#  'A768t',
#  'A770e',
#  'A780e',
#  'A785e',
#  'A788t',
#  'A789',
#  'A798t',
#  'A800',
#  'A805e',
#  'A820',
#  'A820e',
#  'A820t',
#  'A828t',
#  'A830',
#  'A850',
#  'A8-50',
#  'A850+',
#  'A858t',
#  'A860e',
#  'A880',
#  'A889',
#  'A890e',
#  'HD',
#  '1',
#  '90w',
#  'Ascend D1',
#  'Ascend D2',
#  'Ascend G6',
#  'Ascend G7',
#  'Ascend G700',
#  'Ascend G700T',
#  'Ascend GX1',
#  'Ascend P1',
#  'Ascend P6',
#  'Ascend P7',
#  'Ascend P8',
#  'Axon',
#  'Axon Max',
#  'AxonMini',
#  'B199',
#  'B8080-F',
#  'B9388',
#  'BF A500',
#  'BF T18',
#  'BF T18 Plus',
#  'Blade A1',
#  'Blade C',
#  'Blade S6',
#  'Blade S6 Lux',
#  'BM001',
#  'BM002',
#  'BM003',
#  'Butterfly',
#  'Butterfly s',
#  'S+',
#  '5',
#  '5S',
#  'XL',
#  'C03',
#  'C230w',
#  'C630Lw',
#  'C666t',
#  'C730Lw',
#  'C8812',
#  'C8812+',
#  'C8813',
#  'C8813D',
#  'C8813DQ',
#  'C8813Q',
#  'C8815',
#  'C8816',
#  'C8816D',
#  'C8817E',
#  'C8817L',
#  'C8818',
#  'C986t',
#  'C986t+',
#  'x1',
#  'x11S',
#  'x12',
#  'x12A',
#  'x13',
#  'xnote',
#  'xnote2',
#  'xnote3',
#  'xnotea11',
#  'zt_121',
#  ' X1',
#  ' Plus',
#  'Note',
#  'Note3',
#  'NX Plus',
#  'XM',
#  'Compaq 7',
#  ' W2',
#  'CYM1',
#  'D1',
#  'D2-M',
#  'D330',
#  'D350',
#  'D360',
#  'D500',
#  'D516w',
#  'D520',
#  'D557',
#  'D800',
#  'Defy+',
#  'Desire 310',
#  'Desire 5088',
#  'Desire 510',
#  'Desire 609d',
#  'Desire 610t',
#  'Desire 616',
#  'Desire 626',
#  'Desire 7088',
#  'Desire 816',
#  'Desire 816x',
#  'Desire 820',
#  'Desire 820 Mini',
#  'Desire 826',
#  'Desire D316d',
#  'Desire D516d',
#  'Desire D516t',
#  'Desire HD',
#  'Desire S',
#  'Desire V',
#  'Doeasy E700',
#  'DROID RAZR',
#  'DROID RAZR M',
#  'Air',
#  'Max',
#  'mini',
#  'Pro',
#  ' X5',
#  '2 Plus',
#  'A8',
#  'Note8',
#  'S8',
#  '1 Pro',
#  'ihv1',
#  'Max Pro',
#  'metal',
#  'menote1',
#  'menote1 2',
#  'menote13',
#  'VIBE X2',
#  '+',
#  '3C',
#  '3X',
#  '4A',
#  'hu1',
#  'hu1 Plus',
#  'hu1 plus',
#  '7',
#  'T1-823L',
#  '4X',
#  '5X',
#  'T1',
#  'U8860',
#  'V8',
#  'X2',
#  'E1',
#  'E100T',
#  'E1T',
#  'E260-T',
#  'E3',
#  'E5',
#  'E50-T',
#  'E6',
#  'E600M',
#  'E601M',
#  'E602M',
#  'E602T',
#  'E613M',
#  'E619',
#  'E619+',
#  'E620M',
#  'E621T',
#  'E622M',
#  'E625T',
#  'E6T',
#  'E7',
#  'E70-T',
#  'E8',
#  'E820',
#  'E912S',
#  'E99',
#  'EG929',
#  'EG936D',
#  'EG939',
#  'EG966',
#  'EG970',
#  'EG971',
#  'EG978',
#  'EG980',
#  'ELIFE E3T',
#  'ELIFE E6 mini',
#  'ELIFE E7 Mini',
#  'ELIFE S5.5',
#  'EV5',
#  'EVO 3D X515m',
#  'F103',
#  'F103S',
#  'F105',
#  'F2',
#  'F301',
#  'F303',
#  'F320L',
#  'F8909',
#  'Find',
#  'Find 3',
#  'Find 5',
#  'Find 7',
#  'G11',
#  'G2',
#  'G3',
#  'G309T',
#  'G3588V',
#  'G3609',
#  'G3818',
#  'G3819D',
#  'G4',
#  'G510',
#  'G520-0000',
#  'G520-5000',
#  'G520-T10',
#  'G521',
#  'G525',
#  'G606',
#  'G610C',
#  'G610M',
#  'G610S',
#  'G610T',
#  'G615-U10',
#  'G616-L076',
#  'G620-L72',
#  'G620-L75',
#  'G628',
#  'G629',
#  'G630',
#  'G660-L075',
#  'G6-C00',
#  'G6-U00',
#  'G7 Plus',
#  'G716',
#  'G717C',
#  'G718C',
#  'G7200',
#  'G730-C00',
#  'G730-L075',
#  'G730-T00',
#  'G730-U00',
#  'G730-U30',
#  'G750-T20',
#  'G9',
#  'Galaxy A3',
#  'Galaxy A5',
#  'Galaxy A7',
#  'Galaxy A8',
#  'Galaxy Ace',
#  'Galaxy Ace 2',
#  'Galaxy Ace 3',
#  'Galaxy Ace 4',
#  'Galaxy Ace Dear',
#  'Galaxy Ace DUOS',
#  'Galaxy Ace Plus',
#  'Galaxy Alpha',
#  'Galaxy Core',
#  'Galaxy Core 2',
#  'Galaxy Core 4G',
#  'Galaxy Core Advance',
#  'Galaxy Core Lite',
#  'Galaxy Core Max',
#  'Galaxy Core Mini',
#  'Galaxy Core Prime',
#  'Galaxy E7',
#  'Galaxy Fame',
#  'Galaxy Gio',
#  'Galaxy Golden',
#  'Galaxy Grand',
#  'Galaxy Grand 2',
#  'Galaxy Grand 2 LTE',
#  'Galaxy Grand DUOS',
#  'Galaxy Grand Neo Plus',
#  'Galaxy Grand Prime',
#  'Galaxy Infinite',
#  'Galaxy J',
#  'Galaxy J3',
#  'Galaxy J5',
#  'Galaxy J7',
#  'Galaxy K Zoom',
#  'Galaxy Mega 2',
#  'Galaxy Mega 5.8',
#  'Galaxy Mega 6.3',
#  'Galaxy Mega Plus',
#  'Galaxy Mini',
#  'Galaxy Nexus',
#  'Galaxy Note',
#  'Galaxy Note 10.1',
#  'Galaxy Note 10.1 2014 Edition P601',
#  'Galaxy Note 10.1 N8010',
#  'Galaxy Note 2',
#  'Galaxy Note 3',
#  'Galaxy Note 3 Lite',
#  'Galaxy Note 4',
#  'Galaxy Note 5',
#  'Galaxy Note 8.0',
#  'Galaxy Note Edge',
#  'Galaxy On5',
#  'Galaxy On7',
#  'Galaxy Premier',
#  'Galaxy R',
#  'Galaxy S',
#  'Galaxy S Advance',
#  'Galaxy S DUOS',
#  'Galaxy S DUOS 2',
#  'Galaxy S L',
#  'Galaxy S Plus',
#  'Galaxy S2',
#  'Galaxy S2 Epic 4G Touch',
#  'Galaxy S2 HD LTE E120S',
#  'Galaxy S2 Plus',
#  'Galaxy S3',
#  'Galaxy S3 Mini',
#  'Galaxy S3 Neo+',
#  'Galaxy S4',
#  'Galaxy S4 Mini',
#  'Galaxy S4 Zoom',
#  'Galaxy S5',
#  'Galaxy S5 Plus',
#  'Galaxy S6',
#  'Galaxy S6 Edge',
#  'Galaxy S6 Edge+',
#  'Galaxy S7',
#  'Galaxy S7 Edge',
#  'Galaxy Style DUOS',
#  'Galaxy Tab 2 P3100',
#  'Galaxy Tab 2 P5100',
#  'Galaxy Tab 2 P5110',
#  'Galaxy Tab 3 10.1',
#  'Galaxy Tab 3 7.0',
#  'Galaxy Tab 3 8.0',
#  'Galaxy Tab 3 Lite T110',
#  'Galaxy Tab 3 Lite T111',
#  'Galaxy Tab 4 T231',
#  'Galaxy Tab 4 T331C',
#  'Galaxy Tab 7.0 Plus',
#  'Galaxy Tab A 8.0',
#  'Galaxy Tab P1000',
#  'Galaxy Tab P6800',
#  'Galaxy Tab Pro T321',
#  'Galaxy Tab S T705',
#  'Galaxy Tab S T705C',
#  'Galaxy Tab S T805C',
#  'Galaxy Trend',
#  'Galaxy Trend 2',
#  'Galaxy Trend 3',
#  'Galaxy Trend DUOS',
#  'Galaxy Trend DUOS 2',
#  'Galaxy W',
#  'Galaxy Win',
#  'Galaxy Win Pro',
#  'Galaxy Y',
#  'Gigaset ME',
#  'GN100',
#  'GN105',
#  'GN106',
#  'GN108',
#  'GN128',
#  'GN135',
#  'GN137',
#  'GN139',
#  'GN150',
#  'GN151',
#  'GN152',
#  'GN180',
#  'GN305',
#  'GN5001S',
#  'GN5002',
#  'GN700T',
#  'GN700W',
#  'GN705',
#  'GN705T',
#  'GN706L',
#  'GN708T',
#  'GN708W',
#  'GN715',
#  'GN800',
#  'GN810',
#  'GN878',
#  'GN9002',
#  'GN9004',
#  'Grand Memo',
#  'Grand Memo 2',
#  'Grand S 2',
#  'Grand X',
#  'Grand X Quad',
#  'GT7',
#  'GT-I8160',
#  'H1',
#  'H1S',
#  'H2',
#  'H3',
#  'H6',
#  'HN3-U01',
#  'Hol-U10',
#  'HS-U971',
#  'HS-U978',
#  'HT-I857',
#  'HT-I860',
#  'i1',
#  'I6',
#  'i600',
#  'I630M',
#  'I630T',
#  'I632T',
#  'I635T',
#  'I639T',
#  'I699I',
#  'I7',
#  'I779',
#  'I8250',
#  'I8258',
#  'I8268',
#  'I9050',
#  'I9118',
#  'I95',
#  'IdeaTab 2109A',
#  'IdeaTab A1000-T',
#  'IdeaTab A1010-T',
#  'IdeaTab A2207A-H',
#  'IdeaTab A5000-E',
#  'idol X',
#  'idol3',
#  'IPH8',
#  'iPh-800',
#  'iSuper S1',
#  'iSuper S2',
#  'IUSAI US15',
#  'IVO 6600',
#  'IVO 6622',
#  'IVO 6655',
#  'IVO 6666',
#  'IVO 6688',
#  'IVO 8800',
#  'ivvi Pro',
#  'ivvi i',
#  'ivvi K1 mini',
#  'ivvi S6',
#  'J320T',
#  'J636D+',
#  'J738M',
#  'JX8166',
#  'K012',
#  'K1',
#  'K35',
#  'K68w',
#  'K80',
#  'K860',
#  'K860i',
#  'K88L',
#  'K900',
#  'KDOOR X5-Y12',
#  'Kindle Fire HDX 7.0',
#  'King 7',
#  'King 7s',
#  'L1',
#  'L1 mini',
#  'L100',
#  'L108',
#  'L128',
#  'L168',
#  'L22',
#  'L5 mini',
#  'L5 Plus',
#  'L5Pro',
#  'L7',
#  'L70',
#  'L8',
#  'L810',
#  'L82',
#  'L820',
#  'L823',
#  'L855',
#  'L9',
#  'L920',
#  'L930i',
#  'LT01',
#  'LT02',
#  'LT416',
#  'LT988',
#  'M030',
#  'M031',
#  'M032',
#  'M1',
#  'M10-M',
#  'M15',
#  'M2',
#  'M201S',
#  'M20-M',
#  'M20-T',
#  'M210',
#  'M228-M51',
#  'M3',
#  'M310',
#  'm310',
#  'M311',
#  'M3S',
#  'M4',
#  'M4S',
#  'M5',
#  'M5 Plus',
#  'M512',
#  'M560',
#  'M6',
#  'M601',
#  'M6-M7',
#  'M701',
#  'M8',
#  'M811',
#  'M812C',
#  'M8St',
#  'M9',
#  'Mate',
#  'Mate 2',
#  'Mate 7',
#  'mate7es2',
#  'Mate 8',
#  'Mate S',
#  'MAX3',
#  'MC002',
#  'ME371MG',
#  'ME7510KG',
#  'MediaPad 10 FHD',
#  'MediaPad 10 Link',
#  'MediaPad 10 Link+',
#  'MediaPad 7 Vogue',
#  'MediaPad M1',
#  'MediaPad M2-801W',
#  'MediaPad M2-803L',
#  'memo 5S',
#  'meTalV123',
#  'MI 1',
#  'MI 1S',
#  'MI 2',
#  'MI 2A',
#  'MI 2C',
#  'MI 2S',
#  'MI 3',
#  'MI 4',
#  'MI 4S',
#  'MI 5',
#  'MI One C1',
#  'MI One Plus',
#  'MI pad',
#  'MI pad 2',
#  'MK260',
#  'MM1101',
#  'MM1104',
#  'MOMO9',
#  'Mos1',
#  'Moto G',
#  'Moto Turbo',
#  'Moto X',
#  'Moto X 3',
#  'Moto X Pro',
#  'Moto X Style',
#  'Moto12X12',
#  'MT1-U06',
#  'MT2-C00',
#  'MUSE',
#  'MX2',
#  'MX3',
#  'MX4',
#  'MX4 Pro',
#  'MX5',
#  'myone123',
#  'N1',
#  'N1 max',
#  'N1 Mini',
#  'N1T',
#  'N1W',
#  'N1-Y',
#  'N2',
#  'N3',
#  'N798',
#  'N818',
#  'N821',
#  'N828',
#  'N880E',
#  'N880F',
#  'N881F',
#  'N909',
#  'N910C',
#  'N910U',
#  'N919',
#  'N986',
#  'Nexus 4',
#  'Nexus 5',
#  'Nexus 5X',
#  'Nexus 6P',
#  'Nexus 7',
#  'Nexus S',
#  'notev123',
#  'OKA31',
#  'One',
#  'One A9',
#  'One E8',
#  'One E9',
#  'One M8',
#  'One M8 Eye',
#  'One M9',
#  'One M9+',
#  'One M9e',
#  'One max',
#  'One ME',
#  'One S',
#  'One X',
#  'One X9',
#  'ono',
#  'Optimus G',
#  'Optimus G Pro',
#  'Optimus G Pro 2',
#  'Optimus LTE',
#  'P1',
#  'P1c58',
#  'P2',
#  'P3',
#  'P301M',
#  'P302C',
#  'P305',
#  'P306C',
#  'P308L',
#  'P316L',
#  'P318L',
#  'P331M',
#  'P332U',
#  'P335M',
#  'P360W',
#  'P500M',
#  'P501M',
#  'P502U',
#  'P51',
#  'P518L',
#  'P520L',
#  'P596',
#  'P6',
#  'P688L',
#  'P70',
#  'P700',
#  'P700i',
#  'P705',
#  'P770',
#  'P780',
#  'P8',
#  'P8 Lite',
#  'P880',
#  'P8max',
#  'P9',
#  'P9 Plus',
#  'P970',
#  'PHAB Plus',
#  'PRO5',
#  'Q201T',
#  'Q301C',
#  'Q302C',
#  'Q3C',
#  'Q501T',
#  'Q501U',
#  'Q503U',
#  'Q505T',
#  'Q507T',
#  'Q509T',
#  'Q519T',
#  'Q7',
#  'Q701C',
#  'Q705U',
#  'Q801L',
#  'Q802T',
#  'Q805T',
#  'R1',
#  'R1C',
#  'R1S',
#  'R2010',
#  'R2017',
#  'R3',
#  'R5',
#  'R5s plus',
#  'R6007',
#  'R7',
#  'R7 Plus',
#  'R7s',
#  'R8000',
#  'R801',
#  'R805',
#  'R807',
#  'R809T',
#  'R811',
#  'R813T',
#  'R815T',
#  'R817',
#  'R817T',
#  'R819T',
#  'R820',
#  'R8205',
#  'R821T',
#  'R823T',
#  'R827T',
#  'R830',
#  'R830S',
#  'R831S',
#  'R831T',
#  'R833T',
#  'R850',
#  'R9',
#  'R9 Plus',
#  'Razrrv1',
#  'S11T',
#  'S12',
#  'S2',
#  'S2L',
#  'S2y',
#  'S3',
#  'S3+',
#  'S300',
#  'S5',
#  'S5.1',
#  'S5.1Pro',
#  'S5.5L',
#  'S5000',
#  'S5300',
#  'S560',
#  'S5830I',
#  'S5831I',
#  'S6',
#  'S60t',
#  'S650',
#  'S658t',
#  'S660',
#  'S686',
#  'S696',
#  'S6-NT1',
#  'S6T',
#  'S7',
#  ...]

# %%
# Check for empty device_model value as a result of junk character cleanup.
# There are 759 rows with empty device_model value

dfnev[dfnev.device_model =='']
# Out:
#                  device_id phone_brand device_model gender  age group_train
# 3171   3017014922206440000     Coolpad                   M   26      M25-32
# 3209  -6875585507485880000         ZTE                   M   35        M32+
# 3210  -1626954163455960000         ZTE                   M   19       M0-24
# 3211  -3636438210269910000         ZTE                   M   62        M32+
# 3212   1402460368780270000         ZTE                   M   22       M0-24
# ...                    ...         ...          ...    ...  ...         ...
# 22006 -1858458687678460000        Qiku                   M   42        M32+
# 22007 -5109790813747600000        Qiku                   M   24       M0-24
# 22008  7409603864137950000        Qiku                   F   63        F32+
# 22009  2256699559541470000        Qiku                   M   30      M25-32
# 22010   478835366937479000        Qiku                   M   27      M25-32
#
# [759 rows x 6 columns]

# %%
# lets impute empty device_model value
# 
dfnev.replace('','Unknown',inplace=True)

# %%
# Check again for empty device_model value
# 
dfnev[dfnev.device_model =='']
# Out:
# Empty DataFrame
# Columns: [device_id, phone_brand, device_model, gender, age, group_train]
# Index: []

# %%
# Check for empty phone_brand value
# 
dfnev[dfnev.phone_brand =='']
# Out:
# Empty DataFrame
# Columns: [device_id, phone_brand, device_model, gender, age, group_train]
# Index: []

# %%
# Check for unique phone_brand value
print(sorted(dfnev['phone_brand'].unique()))
# Out:
# ['AUX', 'Bacardi', 'Bifer', 'CUBE', 'Changhong', 'Cong', 'Coolpad', 'Ctyon', 'Daq', 'Gionee', 'HTC', 'Huawei', 'Hundred Li Feng', 'JXD', 'Kingsun', 'Konka', 'Ktouch', 'LG', 'LOGO', 'Lovme', 'MIL', 'Meizu', 'Monkey King', 'Noain', 'OPPO', 'Opssom', 'Oukimobile', 'PPTV', 'Phicomm', 'Qiku', 'Ramos', 'SUGAR', 'Sony', 'TCL', 'Taobao', 'Teclast', 'XFPLAY', 'Xiaomi', 'Yitong', 'ZOYE', 'ZTE', 'ZUK', 'ada', 'aiyouni', 'asus', 'banghua', 'bigcola', 'bodao', 'candy', 'ccmc', 'desci', 'dowe', 'epai', 'fks', 'fs', 'google', 'greeno', 'haier', 'hammer', 'hasse', 'heymi', 'hisense', 'ipair', 'kiwu', 'koobee', 'kupo', 'lenovo', 'lingyun', 'lshi', 'meitu', 'mengmi', 'micky', 'mige', 'mole', 'moto', 'newman', 'nibilu', 'nokia', 'nubia', 'nuomi', 'obi', 'oneplus', 'others', 'ouxin', 'panosonic', 'pner', 'samsung', 'smallt', 'vivo', 'weimi', 'weitu', 'wpf', 'xiangmi', 'ximi', 'yougo', 'youmi', 'yuxin']

# %%
dfnev.phone_brand.value_counts()
# Out:
# Xiaomi     17337
# samsung    13706
# Huawei     13001
# OPPO        5802
# vivo        5658
#            ...
# fs             1
# ZOYE           1
# mole           1
# Ctyon          1
# pner           1
# Name: phone_brand, Length: 97, dtype: int64

# %% [markdown]
# ### 2.2 Cleaning events dataset

# %%
dfev.describe()
# Out:
#           device_id      event_id      latitude     longitude           age
# count  1.215598e+06  1.215598e+06  1.215598e+06  1.215598e+06  1.215598e+06
# mean  -3.114047e+16  1.626675e+06  7.839380e+01  2.182751e+01  3.350030e+01
# std    5.322380e+18  9.396631e+05  5.381246e+01  1.564827e+01  9.745476e+00
# min   -9.222957e+18  1.000000e+00 -1.800000e+02 -3.380000e+01  1.100000e+01
# 25%   -4.672948e+18  8.123205e+05  0.000000e+00  0.000000e+00  2.700000e+01
# 50%   -1.188460e+17  1.627310e+06  1.127500e+02  2.857000e+01  3.100000e+01
# 75%    4.631837e+18  2.440380e+06  1.171700e+02  3.401000e+01  3.900000e+01
# max    9.220915e+18  3.252948e+06  1.511800e+02  5.364000e+01  8.900000e+01

# %%
# display dataframe info()
# 
dfev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215598 entries, 0 to 1215597
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   device_id    1215598 non-null  int64
#  1   event_id     1215598 non-null  int64
#  2   event_time   1215598 non-null  object
#  3   latitude     1215598 non-null  float64
#  4   longitude    1215598 non-null  float64
#  5   gender       1215598 non-null  object
#  6   age          1215598 non-null  int64
#  7   group_train  1215598 non-null  object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 74.2+ MB

# %%
# print events dataset shape before cleaning

dfev.shape
# Out:
# (1215598, 8)

# %%
# print few records
# 
dfev.head(5)
# Out:
#              device_id  event_id           event_time  latitude  longitude  \
# 0  4676982795249940000   2958924  2016-05-01 22:03:46    113.24      22.85
# 1  4782582047729160000   2958931  2016-05-01 22:24:09    114.47      38.03
# 2  2181284491650730000   2958933  2016-05-01 22:24:44    125.66      43.02
# 3  4221762657972680000   2958935  2016-05-01 22:40:47    115.19      24.07
# 4 -2990318111507320000   2958938  2016-05-01 21:59:08      0.00       0.00
#
#   gender  age group_train
# 0      M   52        M32+
# 1      M   36        M32+
# 2      M   28      M25-32
# 3      F   19       F0-24
# 4      F   32      F25-32

# %%
# Remove all records where latitude & longitude <=0
# and print the shape
dfev = dfev.loc[(dfev.latitude > 0) & (dfev.longitude > 0)]
dfev.shape
# Out:
# (858777, 8)

# %%
dfev.head(5)
# Out:
#              device_id  event_id           event_time  latitude  longitude  \
# 0  4676982795249940000   2958924  2016-05-01 22:03:46    113.24      22.85
# 1  4782582047729160000   2958931  2016-05-01 22:24:09    114.47      38.03
# 2  2181284491650730000   2958933  2016-05-01 22:24:44    125.66      43.02
# 3  4221762657972680000   2958935  2016-05-01 22:40:47    115.19      24.07
# 5 -6242501228649110000   2958939  2016-05-01 21:59:40    111.21      27.85
#
#   gender  age group_train
# 0      M   52        M32+
# 1      M   36        M32+
# 2      M   28      M25-32
# 3      F   19       F0-24
# 5      M   20       M0-24

# %%
# Checking binary column 'gender' count after cleanup
#
dfev['gender'].value_counts(dropna=False)
# Out:
# M    623391
# F    235386
# Name: gender, dtype: int64

# %% [markdown]
# ### 2.3 Cleaning appdata dataset

# %%
# Print the first 5 rows in the appdata dataset
# 
dfapp.head(5)
# Out:
#    event_id               app_id  is_installed  is_active  label_id  \
# 0   2960967  8557198901083791098           1.0        1.0     548.0
# 1   2960967  8557198901083791098           1.0        1.0     204.0
# 2   2960967  8557198901083791098           1.0        1.0     172.0
# 3   2960967  8557198901083791098           1.0        1.0     223.0
# 4   2960967  8557198901083791098           1.0        1.0     206.0
#
#                category
# 0          Industry tag
# 1        sports and gym
# 2                    IM
# 3  convenience services
# 4               Medical

# %%
# Observation: There are double quotes (") appearing at the beginning of the text. 
# Lets cleanup them
# 
dfapp.category.unique().tolist()
# Out:
# ['Industry tag',
#  'sports and gym',
#  'IM',
#  'convenience services',
#  'Medical',
#  'health',
#  'Property Industry 1.0',
#  'Accounting',
#  'Low Risk',
#  'Low income',
#  'Low liquidity',
#  'Financial Services',
#  'Internet banking',
#  'And the Church',
#  'Custom label',
#  'unknown',
#  'Property Industry 2.0',
#  'Personal Effectiveness 1',
#  'online malls',
#  'fashion',
#  'financial',
#  'P2P net loan',
#  'P2P',
#  'Reviews',
#  'Total Cost 1',
#  '1 free',
#  'Services 1',
#  'free',
#  'Property Industry new',
#  'Bank Credit Card',
#  'Low risk',
#  'Low profitability',
#  'Liquid medium',
#  'Consumer loans',
#  'Bank financing',
#  'news',
#  'Entertainment News',
#  'reading platform',
#  'Internet Securities',
#  '"online shopping',
#  'online shopping navigation',
#  'poker game_doudizhu',
#  'Cute style comic',
#  'Cards RPG',
#  'knight game',
#  'Turn based RPG game',
#  'Stimulate fun',
#  'Customization',
#  'Enthusiasm',
#  'Tencent',
#  'game',
#  'Health Management',
#  'novels',
#  'millitary and wars',
#  'game-tank',
#  'game-Tactics',
#  'Irritation / Fun 1',
#  'Heritage Foundation',
#  'Personal Effectiveness',
#  'video',
#  'tourism product',
#  'flight',
#  'Air Travel',
#  'travel',
#  'Booking channels',
#  'Integrated Air Travel Booking',
#  'music',
#  'Cozy 1',
#  'Pay',
#  'Finance',
#  'Moderate profitability',
#  'High Flow',
#  'Third party payment',
#  'pictures photography',
#  'comics',
#  'Internet Banking',
#  'fund',
#  'Monetary Fund',
#  'IMF',
#  'Science and Technology',
#  'mobile bank',
#  'Direct Banking',
#  'Direct Bank',
#  'fixed income',
#  'pursue',
#  'community',
#  'Car Owners',
#  'Condition of the vehicles',
#  'Simple 1',
#  'Nature 1',
#  'Pursuit 1',
#  'foreign language',
#  'Relatives 1',
#  '1 vitality',
#  'Securities',
#  'High risk',
#  'High profitability',
#  'Commodity Futures',
#  'Stock Futures',
#  'Business simulation',
#  'Debit and credit',
#  'Wealth Management',
#  'Higher income',
#  'radio',
#  'High mobility',
#  'A shares',
#  'stock',
#  'education outside class',
#  'network disk',
#  'Technology Information',
#  'Taxi',
#  'Customized 1',
#  'weibo',
#  'Weather',
#  'game-Music and Dance',
#  'Passion 1',
#  'Housing Advice',
#  'Jobs',
#  'Trendy / cool 1',
#  'game-pet',
#  'farm',
#  'game-Racing',
#  'Racing (RAC)',
#  'Mother',
#  'Parenting',
#  'Maternal and child supplies',
#  'Prepare pregnant pregnancy',
#  'Maternal and child population',
#  'Pregnant baby',
#  'Coach reservations',
#  'Bus',
#  'map',
#  'game-Cartoon',
#  'Third-party card management',
#  'business',
#  '"online shopping by group',
#  'the film',
#  'Buy class',
#  'Sports News',
#  'notes',
#  'takeaway ordering',
#  'Automotive News',
#  'Smart Shopping 1',
#  'Quality 1',
#  'Consumer Finance',
#  '3 kindom game',
#  'Integrated Living',
#  'The elimination of class',
#  'Car',
#  'other',
#  'Lottery ticket',
#  'DS_P2P net loan',
#  'Science and Technology 1',
#  'Overseas travel',
#  'study abroad',
#  'Purpose of travel',
#  'Online booking class',
#  'Relatives',
#  'Trendy / cool',
#  'show',
#  'Integrated tourism',
#  'literature',
#  'read',
#  'japanese comic and animation',
#  'comfortable',
#  'game-Puzzle',
#  'Smart Appliances',
#  'Calendar',
#  'Scheduling',
#  'service',
#  '1 reputation',
#  'children books',
#  'education for babies',
#  'Families with babies',
#  'Parenting stage',
#  'Casual puzzle categories',
#  'Financial Information',
#  'coach transport',
#  'Cool trendy',
#  'Texas Poker',
#  'Chess categories',
#  'Reputation',
#  'Financial Supermarket',
#  'Traditional securities brokerage',
#  'Precious Metals',
#  'train',
#  'High-speed rail train reservation',
#  'Smart Shopping',
#  'Recipes',
#  'Crowdfunding financing',
#  'Equity Fund',
#  'Other Read',
#  'Direct Insurance',
#  'Medium risk',
#  'Lower liquidity',
#  'Insurance',
#  'chess',
#  'Listening to books category',
#  'tribe',
#  'SLG (strategy)',
#  'gaming strategy',
#  'magazine and journal',
#  'Hotel application',
#  'Book hotel complex',
#  'Wearable Health',
#  'coupon',
#  'Peace - Search',
#  'Ping',
#  'File Editor',
#  'Noble 1',
#  'love and marriage',
#  'game-Fishing',
#  'blogs',
#  'dictionary',
#  'game-Adventure puzzle',
#  'Hotels',
#  'Hotel Type',
#  'Hotel Chain',
#  'Travel Travel',
#  'aviation',
#  'Aviation Integrated Services',
#  'Aeronautical Information Service',
#  'checkpoints game',
#  'game-Parkour',
#  'casual games',
#  'store management',
#  'Prepare baby',
#  'lose weight',
#  'Travel Information',
#  'Free exercise',
#  'picture sharing',
#  'A beauty care',
#  'Sea Amoy',
#  'Buy',
#  'Decoration',
#  'Contacts',
#  'Crowdfunding',
#  'navigation',
#  'Appliances',
#  'professional skills',
#  'realistic style comic',
#  'Utilities',
#  'Total Cost',
#  'game-Answer',
#  'Integrated ticket reservation',
#  'readers',
#  'science',
#  'library',
#  'Traditional Insurance',
#  'Life Insurance',
#  'sports',
#  'majiang',
#  'Flight area',
#  'Chinese mainland (Airlines)',
#  'Airline type',
#  'Full Service Airlines',
#  'table game',
#  'Express',
#  'class managemetn',
#  'College Students',
#  'Occupational identity',
#  'Points Activities',
#  'exams',
#  'game-Role -playing games',
#  'japanese and korean style',
#  'magic',
#  'art and culture',
#  'game-Box',
#  'fashion outfit',
#  'ARPG',
#  'Cultivation fantasy game',
#  'Travel advisory',
#  '80s Japanese comic',
#  'realtime fighting',
#  'gambling',
#  'exchange rate',
#  'futures',
#  'System Tools',
#  'joke',
#  'poker',
#  'vitality',
#  'Pirated content',
#  'zombies game',
#  'Behalf of the drive',
#  'Astrology Horoscope',
#  'Animation',
#  'Comics Reading Tools',
#  'Audiobooks',
#  'Sale of cars',
#  'Tour around',
#  'Non-standard accommodation',
#  "Read the operator's",
#  'Editor',
#  'Rentals',
#  'Exchange',
#  'Parkour avoid class',
#  'game-stress reliever',
#  'Academic Information',
#  'Animation aggregate class',
#  'business cards',
#  'Hardware Related',
#  'quality',
#  'Domestic travel',
#  'Sellers',
#  'game-Competitive action',
#  'game-shooting',
#  'round',
#  'poetry',
#  'Travel preferences',
#  'Share Tour',
#  'Beauty Nail',
#  'game-Lianliankan',
#  'App Store',
#  'game-Business simulation',
#  'cosplay',
#  'Intellectual development game',
#  'Share Travels',
#  'management',
#  'football',
#  'Smart Home',
#  'game-Bobble',
#  'Families with small babies',
#  'Families with big baby',
#  'Puzzle',
#  'Low Cost Airlines',
#  'game-Horizontal version',
#  '90s Japanese comic',
#  'chinese comic',
#  'game-flight',
#  'Flight Shooting',
#  'User Community',
#  'natural',
#  'Shootout Shooting (STG)',
#  'game-Snipe',
#  'strategy game',
#  'Card Game',
#  'action games',
#  'science fiction',
#  'US and Europe animation',
#  'basketball',
#  'Sports',
#  'war chess',
#  'game-Cutting things',
#  'Internet Insurance',
#  'Vermicelli',
#  'Simulators',
#  'billards',
#  'US and Europe magic comic',
#  'Chess game',
#  'movie',
#  'Business Office',
#  'Classical 1',
#  'Journey to the West game',
#  'MOBA',
#  'game-Finding fault',
#  'Destination Region',
#  'Japan and South Korea (Travel)',
#  'shopping sharing',
#  'MMO',
#  'pixel style comic',
#  'game-card',
#  'safety Insurance',
#  'World of Warcraft',
#  'Ninja',
#  'game-aircraft',
#  'violence comic',
#  'Housekeeping',
#  'old style game',
#  'Other shares',
#  'Engineering Drawing',
#  'classical',
#  'Southeast Asia (aviation)',
#  'KTV',
#  'WIFI',
#  'Estate',
#  'game-Motorcycle',
#  'noble',
#  'household products',
#  'Make-up application',
#  'entertainment',
#  'Doctors',
#  'Chinese painting',
#  'Clock',
#  'Racing games',
#  'Sports Games',
#  'Adventure Game',
#  'pet raising up',
#  'Xian Xia',
#  'Music Games',
#  'Skin care applications',
#  'H shares',
#  'game-gem',
#  'Information',
#  'High-end hotel',
#  'Financial Futures',
#  'math',
#  'Jin Yong',
#  'Literacy Games',
#  'Simple',
#  'game-Zuma',
#  '"Europe',
#  'dotal-lol',
#  'other ball game',
#  'phone',
#  'Trust',
#  'Regional Aviation',
#  'email',
#  'Puzzles',
#  'Southeast Asia (Travel)',
#  '"Hong Kong',
#  'Tower Defense',
#  'game-3D',
#  'Man playing favorites',
#  'love raising up',
#  'Furniture',
#  'Western Mythology',
#  'Family Games',
#  'tennis',
#  'Table Games',
#  'Antique collection',
#  'Games',
#  'Martial arts',
#  'Class animation community',
#  'shows',
#  'reality show',
#  'game-Rowing',
#  'Chinese Classical Mythology',
#  'puzzel',
#  'Senki',
#  'Desktop Enhancements',
#  'Shushan',
#  'sailing game',
#  'business strategy game',
#  'RPG game',
#  'Beach landing game',
#  'airport',
#  'Educational games',
#  'effort',
#  'poker and chess',
#  'mesasge',
#  'Romance',
#  'psychology',
#  'fighting game',
#  'raising up game',
#  'Outlaws of the Marsh game',
#  'Children puzzle game',
#  'game-Gem Elimination',
#  'game-Art Style',
#  'game-game type',
#  'Airline Alliances',
#  'Trust funds',
#  'game-Leisure time',
#  'search',
#  'Guard tower defense game',
#  'Domestic animation',
#  nan]

# %%
# Strip-off double quote from categry.
# 
dfapp['category'] = dfapp['category'].str.strip('"')

# %%
dfapp.category.unique().tolist()
# Out:
# ['Industry tag',
#  'sports and gym',
#  'IM',
#  'convenience services',
#  'Medical',
#  'health',
#  'Property Industry 1.0',
#  'Accounting',
#  'Low Risk',
#  'Low income',
#  'Low liquidity',
#  'Financial Services',
#  'Internet banking',
#  'And the Church',
#  'Custom label',
#  'unknown',
#  'Property Industry 2.0',
#  'Personal Effectiveness 1',
#  'online malls',
#  'fashion',
#  'financial',
#  'P2P net loan',
#  'P2P',
#  'Reviews',
#  'Total Cost 1',
#  '1 free',
#  'Services 1',
#  'free',
#  'Property Industry new',
#  'Bank Credit Card',
#  'Low risk',
#  'Low profitability',
#  'Liquid medium',
#  'Consumer loans',
#  'Bank financing',
#  'news',
#  'Entertainment News',
#  'reading platform',
#  'Internet Securities',
#  'online shopping',
#  'online shopping navigation',
#  'poker game_doudizhu',
#  'Cute style comic',
#  'Cards RPG',
#  'knight game',
#  'Turn based RPG game',
#  'Stimulate fun',
#  'Customization',
#  'Enthusiasm',
#  'Tencent',
#  'game',
#  'Health Management',
#  'novels',
#  'millitary and wars',
#  'game-tank',
#  'game-Tactics',
#  'Irritation / Fun 1',
#  'Heritage Foundation',
#  'Personal Effectiveness',
#  'video',
#  'tourism product',
#  'flight',
#  'Air Travel',
#  'travel',
#  'Booking channels',
#  'Integrated Air Travel Booking',
#  'music',
#  'Cozy 1',
#  'Pay',
#  'Finance',
#  'Moderate profitability',
#  'High Flow',
#  'Third party payment',
#  'pictures photography',
#  'comics',
#  'Internet Banking',
#  'fund',
#  'Monetary Fund',
#  'IMF',
#  'Science and Technology',
#  'mobile bank',
#  'Direct Banking',
#  'Direct Bank',
#  'fixed income',
#  'pursue',
#  'community',
#  'Car Owners',
#  'Condition of the vehicles',
#  'Simple 1',
#  'Nature 1',
#  'Pursuit 1',
#  'foreign language',
#  'Relatives 1',
#  '1 vitality',
#  'Securities',
#  'High risk',
#  'High profitability',
#  'Commodity Futures',
#  'Stock Futures',
#  'Business simulation',
#  'Debit and credit',
#  'Wealth Management',
#  'Higher income',
#  'radio',
#  'High mobility',
#  'A shares',
#  'stock',
#  'education outside class',
#  'network disk',
#  'Technology Information',
#  'Taxi',
#  'Customized 1',
#  'weibo',
#  'Weather',
#  'game-Music and Dance',
#  'Passion 1',
#  'Housing Advice',
#  'Jobs',
#  'Trendy / cool 1',
#  'game-pet',
#  'farm',
#  'game-Racing',
#  'Racing (RAC)',
#  'Mother',
#  'Parenting',
#  'Maternal and child supplies',
#  'Prepare pregnant pregnancy',
#  'Maternal and child population',
#  'Pregnant baby',
#  'Coach reservations',
#  'Bus',
#  'map',
#  'game-Cartoon',
#  'Third-party card management',
#  'business',
#  'online shopping by group',
#  'the film',
#  'Buy class',
#  'Sports News',
#  'notes',
#  'takeaway ordering',
#  'Automotive News',
#  'Smart Shopping 1',
#  'Quality 1',
#  'Consumer Finance',
#  '3 kindom game',
#  'Integrated Living',
#  'The elimination of class',
#  'Car',
#  'other',
#  'Lottery ticket',
#  'DS_P2P net loan',
#  'Science and Technology 1',
#  'Overseas travel',
#  'study abroad',
#  'Purpose of travel',
#  'Online booking class',
#  'Relatives',
#  'Trendy / cool',
#  'show',
#  'Integrated tourism',
#  'literature',
#  'read',
#  'japanese comic and animation',
#  'comfortable',
#  'game-Puzzle',
#  'Smart Appliances',
#  'Calendar',
#  'Scheduling',
#  'service',
#  '1 reputation',
#  'children books',
#  'education for babies',
#  'Families with babies',
#  'Parenting stage',
#  'Casual puzzle categories',
#  'Financial Information',
#  'coach transport',
#  'Cool trendy',
#  'Texas Poker',
#  'Chess categories',
#  'Reputation',
#  'Financial Supermarket',
#  'Traditional securities brokerage',
#  'Precious Metals',
#  'train',
#  'High-speed rail train reservation',
#  'Smart Shopping',
#  'Recipes',
#  'Crowdfunding financing',
#  'Equity Fund',
#  'Other Read',
#  'Direct Insurance',
#  'Medium risk',
#  'Lower liquidity',
#  'Insurance',
#  'chess',
#  'Listening to books category',
#  'tribe',
#  'SLG (strategy)',
#  'gaming strategy',
#  'magazine and journal',
#  'Hotel application',
#  'Book hotel complex',
#  'Wearable Health',
#  'coupon',
#  'Peace - Search',
#  'Ping',
#  'File Editor',
#  'Noble 1',
#  'love and marriage',
#  'game-Fishing',
#  'blogs',
#  'dictionary',
#  'game-Adventure puzzle',
#  'Hotels',
#  'Hotel Type',
#  'Hotel Chain',
#  'Travel Travel',
#  'aviation',
#  'Aviation Integrated Services',
#  'Aeronautical Information Service',
#  'checkpoints game',
#  'game-Parkour',
#  'casual games',
#  'store management',
#  'Prepare baby',
#  'lose weight',
#  'Travel Information',
#  'Free exercise',
#  'picture sharing',
#  'A beauty care',
#  'Sea Amoy',
#  'Buy',
#  'Decoration',
#  'Contacts',
#  'Crowdfunding',
#  'navigation',
#  'Appliances',
#  'professional skills',
#  'realistic style comic',
#  'Utilities',
#  'Total Cost',
#  'game-Answer',
#  'Integrated ticket reservation',
#  'readers',
#  'science',
#  'library',
#  'Traditional Insurance',
#  'Life Insurance',
#  'sports',
#  'majiang',
#  'Flight area',
#  'Chinese mainland (Airlines)',
#  'Airline type',
#  'Full Service Airlines',
#  'table game',
#  'Express',
#  'class managemetn',
#  'College Students',
#  'Occupational identity',
#  'Points Activities',
#  'exams',
#  'game-Role -playing games',
#  'japanese and korean style',
#  'magic',
#  'art and culture',
#  'game-Box',
#  'fashion outfit',
#  'ARPG',
#  'Cultivation fantasy game',
#  'Travel advisory',
#  '80s Japanese comic',
#  'realtime fighting',
#  'gambling',
#  'exchange rate',
#  'futures',
#  'System Tools',
#  'joke',
#  'poker',
#  'vitality',
#  'Pirated content',
#  'zombies game',
#  'Behalf of the drive',
#  'Astrology Horoscope',
#  'Animation',
#  'Comics Reading Tools',
#  'Audiobooks',
#  'Sale of cars',
#  'Tour around',
#  'Non-standard accommodation',
#  "Read the operator's",
#  'Editor',
#  'Rentals',
#  'Exchange',
#  'Parkour avoid class',
#  'game-stress reliever',
#  'Academic Information',
#  'Animation aggregate class',
#  'business cards',
#  'Hardware Related',
#  'quality',
#  'Domestic travel',
#  'Sellers',
#  'game-Competitive action',
#  'game-shooting',
#  'round',
#  'poetry',
#  'Travel preferences',
#  'Share Tour',
#  'Beauty Nail',
#  'game-Lianliankan',
#  'App Store',
#  'game-Business simulation',
#  'cosplay',
#  'Intellectual development game',
#  'Share Travels',
#  'management',
#  'football',
#  'Smart Home',
#  'game-Bobble',
#  'Families with small babies',
#  'Families with big baby',
#  'Puzzle',
#  'Low Cost Airlines',
#  'game-Horizontal version',
#  '90s Japanese comic',
#  'chinese comic',
#  'game-flight',
#  'Flight Shooting',
#  'User Community',
#  'natural',
#  'Shootout Shooting (STG)',
#  'game-Snipe',
#  'strategy game',
#  'Card Game',
#  'action games',
#  'science fiction',
#  'US and Europe animation',
#  'basketball',
#  'Sports',
#  'war chess',
#  'game-Cutting things',
#  'Internet Insurance',
#  'Vermicelli',
#  'Simulators',
#  'billards',
#  'US and Europe magic comic',
#  'Chess game',
#  'movie',
#  'Business Office',
#  'Classical 1',
#  'Journey to the West game',
#  'MOBA',
#  'game-Finding fault',
#  'Destination Region',
#  'Japan and South Korea (Travel)',
#  'shopping sharing',
#  'MMO',
#  'pixel style comic',
#  'game-card',
#  'safety Insurance',
#  'World of Warcraft',
#  'Ninja',
#  'game-aircraft',
#  'violence comic',
#  'Housekeeping',
#  'old style game',
#  'Other shares',
#  'Engineering Drawing',
#  'classical',
#  'Southeast Asia (aviation)',
#  'KTV',
#  'WIFI',
#  'Estate',
#  'game-Motorcycle',
#  'noble',
#  'household products',
#  'Make-up application',
#  'entertainment',
#  'Doctors',
#  'Chinese painting',
#  'Clock',
#  'Racing games',
#  'Sports Games',
#  'Adventure Game',
#  'pet raising up',
#  'Xian Xia',
#  'Music Games',
#  'Skin care applications',
#  'H shares',
#  'game-gem',
#  'Information',
#  'High-end hotel',
#  'Financial Futures',
#  'math',
#  'Jin Yong',
#  'Literacy Games',
#  'Simple',
#  'game-Zuma',
#  'Europe',
#  'dotal-lol',
#  'other ball game',
#  'phone',
#  'Trust',
#  'Regional Aviation',
#  'email',
#  'Puzzles',
#  'Southeast Asia (Travel)',
#  'Hong Kong',
#  'Tower Defense',
#  'game-3D',
#  'Man playing favorites',
#  'love raising up',
#  'Furniture',
#  'Western Mythology',
#  'Family Games',
#  'tennis',
#  'Table Games',
#  'Antique collection',
#  'Games',
#  'Martial arts',
#  'Class animation community',
#  'shows',
#  'reality show',
#  'game-Rowing',
#  'Chinese Classical Mythology',
#  'puzzel',
#  'Senki',
#  'Desktop Enhancements',
#  'Shushan',
#  'sailing game',
#  'business strategy game',
#  'RPG game',
#  'Beach landing game',
#  'airport',
#  'Educational games',
#  'effort',
#  'poker and chess',
#  'mesasge',
#  'Romance',
#  'psychology',
#  'fighting game',
#  'raising up game',
#  'Outlaws of the Marsh game',
#  'Children puzzle game',
#  'game-Gem Elimination',
#  'game-Art Style',
#  'game-game type',
#  'Airline Alliances',
#  'Trust funds',
#  'game-Leisure time',
#  'search',
#  'Guard tower defense game',
#  'Domestic animation',
#  nan]

# %% [markdown]
# ## TASK 3 -  Visualisation

# %% [markdown]
# ### 3.1 Plot appropriate graphs which represent the distribution of Age and gender in the Dataset [Univariate]

# %%
# Get the count of males and females in the event and non-event data set grouped by the age group (0-24,25-32, 32+)
# 
nev_males = dfnev[dfnev['group_train'].isin(['M0-24','M25-32','M32+'])]['group_train'].value_counts()
nev_females= dfnev[dfnev['group_train'].isin(['F0-24','F25-32','F32+'])]['group_train'].value_counts()
ev_males = dfev[dfev['group_train'].isin(['M0-24','M25-32','M32+'])]['group_train'].value_counts()
ev_females= dfev[dfev['group_train'].isin(['F0-24','F25-32','F32+'])]['group_train'].value_counts()

# %%
print("non event data set - males")
print(nev_males)
print(" ")
print("non event data set - females")
print(nev_females)
print(" ")
print("event data set - males")
print(ev_males)
print(" ")
print("event data set - females")
print(ev_females)
# Out:
# non event data set - males
# M25-32    19901
# M32+      16316
# M0-24     11818
# Name: group_train, dtype: int64
#
# non event data set - females
# F25-32    10741
# F32+       9780
# F0-24      6284
# Name: group_train, dtype: int64
#
# event data set - males
# M32+      280345
# M25-32    253719
# M0-24      89327
# Name: group_train, dtype: int64
#
# event data set - females
# F32+      112313
# F25-32     87253
# F0-24      35820
# Name: group_train, dtype: int64

# %%
# This is for charting purposes
# Attach a text label above each bar in *rects*, displaying its height.
# 
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %% [markdown]
# #### 3.1.1 Non-Event Dataset

# %%
labels = ['0-24', '25-32', '32+']
nev_males = nev_males.tolist()
nev_femals = nev_females.tolist()
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize=(8,6))
rects1 = ax.bar(x - width/2, nev_males, width, label='Male')
rects2 = ax.bar(x + width/2, nev_females, width, label='Female')
ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Distribution by Age Group and Gender in Non-Event Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### 3.1.2 Event dataset

# %%
labels = ['0-24', '25-32', '32+']
ev_males = ev_males.tolist()
ev_femals = ev_females.tolist()
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots(figsize=(8,6))
rects1 = ax.bar(x - width/2, ev_males, width, label='Male')
rects2 = ax.bar(x + width/2, ev_females, width, label='Female')
ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Distribution by Age Group and Gender in Event Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### 4.2 Boxplot analysis for gender and Age [Bivariate]

# %% [markdown]
# #### 4.2.1 Non-Event dataset

# %%
# Printing the statistics for non-event data set
# with Gender == Female
# 
df_tmp1 =  dfnev.loc[dfnev.gender=='F']
df_tmp1['age'].describe()
# Out:
# count    26805.000000
# mean        32.051483
# std         10.539238
# min         10.000000
# 25%         25.000000
# 50%         29.000000
# 75%         37.000000
# max         96.000000
# Name: age, dtype: float64

# %%
# Printing the statistics for non-event data set 
# with Gender == Male
# 
df_tmp2 =  dfnev.loc[dfnev.gender=='M']
df_tmp2['age'].describe()
# Out:
# count    48035.000000
# mean        31.048798
# std          9.452689
# min          1.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         90.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.boxplot(y='age', x='gender', 
                 data=dfnev, 
                 palette='colorblind'                 
            )
plt.title('Distribution by Age and Gender in Non-Event Dataset')
plt.show()

# %% [markdown]
# #### 4.2.2 Event Dataset

# %%
# Printing the statistics for event data set
# with Gender == Female
# 
df_tmp3 =  dfev.loc[dfev.gender=='F']
df_tmp3['age'].describe()
# Out:
# count    235386.000000
# mean         34.362940
# std          10.604955
# min          16.000000
# 25%          27.000000
# 50%          32.000000
# 75%          41.000000
# max          86.000000
# Name: age, dtype: float64

# %%
# Printing the statistics for event data set
# with Gender == Male
# 
df_tmp4 =  dfev.loc[dfev.gender=='M']
df_tmp4['age'].describe()
# Out:
# count    623391.000000
# mean         33.337809
# std           9.393527
# min          14.000000
# 25%          27.000000
# 50%          31.000000
# 75%          38.000000
# max          88.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.boxplot(y='age', x='gender', 
                 data=dfev, 
                 palette='colorblind'                 
            )
plt.title('Distribution by Age and Gender in Event Dataset')
plt.show()

# %% [markdown]
# #### 4.3. Plot percentage of device_ids with and without event data

# %%
nev_deviceid_count = dfnev['device_id'].unique().size
ev_deviceid_count = dfev['device_id'].unique().size
total_devices_cnt = nev_deviceid_count + ev_deviceid_count
fig, ax = plt.subplots(figsize=(8,6))
labels = ['Non-Event', 'Event']
device_perc = [(nev_deviceid_count/total_devices_cnt)*100, (ev_deviceid_count/total_devices_cnt)*100]
ax.bar(labels,device_perc)
plt.title('Percentage of device_ids with and without event data')
plt.ylabel('Percentage')

plt.annotate('{:.2f}'.format(device_perc[0])+'%', # this is the text
             (0,device_perc[0]), # this is the point to label
             textcoords="offset points", # how to position the text
             xytext=(0,10), # distance from text to points (x,y)
             ha='center', # horizontal alignment
             va = 'center') # vertica alignment
plt.annotate('{:.2f}'.format(device_perc[1])+'%', # this is the text
             (1,device_perc[1]), # this is the point to label
             textcoords="offset points", # how to position the text
             xytext=(0,10), # distance from text to points (x,y)
             ha='center', # horizontal alignment
             va = 'center') # vertica alignment
fig.tight_layout()
plt.show()

# %% [markdown]
# #### 4.4 Graph representing the distribution of events on different days of a week

# %%
dfev.head(5)
# Out:
#              device_id  event_id           event_time  latitude  longitude  \
# 0  4676982795249940000   2958924  2016-05-01 22:03:46    113.24      22.85
# 1  4782582047729160000   2958931  2016-05-01 22:24:09    114.47      38.03
# 2  2181284491650730000   2958933  2016-05-01 22:24:44    125.66      43.02
# 3  4221762657972680000   2958935  2016-05-01 22:40:47    115.19      24.07
# 5 -6242501228649110000   2958939  2016-05-01 21:59:40    111.21      27.85
#
#   gender  age group_train
# 0      M   52        M32+
# 1      M   36        M32+
# 2      M   28      M25-32
# 3      F   19       F0-24
# 5      M   20       M0-24

# %%
days_of_week = pd.to_datetime(dfev['event_time'], format='%Y-%m-%d').dt.day_name()
pd.Categorical(days_of_week, categories=['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
    ordered=True).value_counts()
# Out:
# Sunday       115984
# Monday       120617
# Tuesday      128733
# Wednesday    127601
# Thursday     127299
# Friday       122047
# Saturday     116496
# dtype: int64

# %%
# Week days are categorised using pd.Categorical then sorted
# 
plt.figure(figsize=(8,6))
days_of_week = pd.to_datetime(dfev['event_time'], format='%Y-%m-%d').dt.day_name()
pd.Categorical(days_of_week, categories=['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
    ordered=True).value_counts().plot(kind='barh')
plt.title('Distribution of events on different days of a week')
plt.xlabel('Number of events')
plt.show()

# %% [markdown]
# #### 4.5 Graph representing the distribution of events per hour [ For one-week data]

# %%
#whole dataset is covered, not just one-week data
plt.figure(figsize=(11,9))
event_hours = pd.to_datetime(dfev['event_time']).dt.hour
event_hours.value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of events per hour')
plt.ylabel('Number of events')
plt.xlabel('Hour')
plt.show()

# %% [markdown]
# #### 4.6 The difference in the distribution of events per hour for Male and Females?  [Show the difference using an appropriate chart for one-week data]

# %%
fig, ax = plt.subplots(figsize=(8,6))
dfmale = dfev.loc[(dfev.gender == 'M')]
dffemale = dfev.loc[(dfev.gender == 'F')]
male_ev_hrs = pd.to_datetime(dfmale['event_time']).dt.hour
male_ev_hrs = male_ev_hrs.value_counts().sort_index()
female_ev_hrs = pd.to_datetime(dffemale['event_time']).dt.hour
female_ev_hrs = female_ev_hrs.value_counts().sort_index()
hours_range = male_ev_hrs.index.tolist()
x = male_ev_hrs.values.tolist()
y = female_ev_hrs.values.tolist()
plt.scatter(hours_range, x, color='r', label='Male')
plt.scatter(hours_range, y, color='g', label='Female')
plt.title('Distribution of events per hour for Male and Females')
plt.xlabel('Hours')
plt.ylabel('Distributon of Events')
plt.legend()
plt.show()

# %% [markdown]
# #### 4.7 Is there any difference in the distribution of Events for different Age Groups over different days of the week? [Consider the age groups as 0-24, 25-32, 33-45, 46+]

# %%
#dfev.groupby([pd.to_datetime(dfev['event_time'], format='%Y-%m-%d').dt.day_name(), 'group_train']).size().unstack().plot(kind='barh', stacked=True)
# 
dfsubset = dfev[['age','event_time']]
age_bins = pd.cut(dfsubset['age'], bins=[0, 24, 33, 46,100],labels=['0-24','25-32','33-45','46+'])
week_days = pd.Categorical(pd.to_datetime(dfsubset['event_time'], format='%Y-%m-%d').dt.day_name(),categories=['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
    ordered=True)
grouped = dfsubset.groupby([week_days, age_bins])
fig, ax1 = plt.subplots(figsize=(11,9))
grouped.size().unstack().plot(kind='bar', stacked=True, ax = ax1)
fig.tight_layout()
plt.title('Distribution of Events for different Age Groups over different days of the week')
plt.xlabel('Week days')
plt.ylabel('Events')
plt.legend()
plt.show()

# %% [markdown]
# #### 4.8.Stacked bar chart for top 10 mobile brands across male and female consumers

# %%
# Feeling the dataset before plot - part #1
#
dfsubset = dfnev[['phone_brand','gender']]
grouped = dfsubset.groupby(['phone_brand', 'gender'])['phone_brand'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(18)
grouped.sort_values(by=['count'], ascending=False)
# Out:
#     phone_brand gender  count
# 66       Xiaomi      M  11407
# 20       Huawei      M   8744
# 160     samsung      M   8263
# 65       Xiaomi      F   5930
# 159     samsung      F   5443
# 19       Huawei      F   4257
# 38        Meizu      M   3404
# 44         OPPO      M   3221
# 164        vivo      M   2998
# 163        vivo      F   2660
# 43         OPPO      F   2581
# 12      Coolpad      M   2270
# 122      lenovo      M   1801
# 37        Meizu      F   1306
# 11      Coolpad      F   1079
# 121      lenovo      F    894
# 16       Gionee      M    721
# 18          HTC      M    694

# %%
# Feeling the dataset before plot - part #2
#
dfsubset = dfnev[['phone_brand','gender']]
grouped = dfsubset.groupby(['phone_brand', 'gender'])['phone_brand'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(18)
grouped.sort_values(by=['phone_brand'], ascending=False)
# Out:
#     phone_brand gender  count
# 163        vivo      F   2660
# 164        vivo      M   2998
# 160     samsung      M   8263
# 159     samsung      F   5443
# 121      lenovo      F    894
# 122      lenovo      M   1801
# 66       Xiaomi      M  11407
# 65       Xiaomi      F   5930
# 44         OPPO      M   3221
# 43         OPPO      F   2581
# 38        Meizu      M   3404
# 37        Meizu      F   1306
# 20       Huawei      M   8744
# 19       Huawei      F   4257
# 18          HTC      M    694
# 16       Gionee      M    721
# 12      Coolpad      M   2270
# 11      Coolpad      F   1079

# %%
dfsubset = dfnev[['phone_brand','gender']]
dfsubset[dfsubset['phone_brand']=='HTC']['gender'].value_counts()
# Out:
# M    694
# F    321
# Name: gender, dtype: int64

# %%
dfsubset = dfnev[['phone_brand','gender']]
dfsubset[dfsubset['phone_brand']=='Gionee']['gender'].value_counts()
# Out:
# M    721
# F    403
# Name: gender, dtype: int64

# %%
N = 10
ind = np.arange(N)    # the x locations for the groups
male_list = grouped[grouped.gender == 'M']['count'].tolist()
female_list = grouped[grouped.gender == 'F']['count'].tolist()
female_list.append(0)      #Gionee not available for Female in top 10, hence mark 0 for Gionee-Female
female_list.append(0)      #HTC not available for Female in top 10 , hence mark 0 for HTC-Female
phone_list = grouped.phone_brand.unique().tolist()
plt.figure(figsize=(9,7))
p1 = plt.bar(ind, male_list, label='Male')
p2 = plt.bar(ind, female_list, bottom=male_list,label='Female')
plt.title('Top 10 mobile brands across male and female')
plt.xlabel('Phone Brand')
plt.ylabel('Count')
plt.xticks(ind, phone_list, rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# #### 4.9 Chart representing ten frequent applications and their respective male and female percentage

# %%
#feel the dataset before plotting.
dfevsub = dfev[['event_id','gender']]
dfappsub = dfapp[['event_id','app_id']]
dfjoin = pd.merge(dfevsub, dfappsub, how='inner', on='event_id')
dfjoin = dfjoin.drop_duplicates()
grouped = dfjoin.groupby(['app_id', 'gender'])['app_id'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(11)
#grouped.sort_values(by=['app_id', 'count'], ascending=[True, False])
grouped.sort_values(by=['count'], ascending=False)
#observation
#===========
#app_id 5927333115845830913 'F' is not available
#app_id 4348659952760821294 'F' is not available
#app_id 628020936226491308 'F' is not available
#app_id 3433289601737013244 'F' is not available
#app_id 7348340405200054701 'F' is not available
#app_id 6284164581582112235 'F' is not available
#app_id -5368809411346728624 'F' is not available
#app_id 8948670408023620661 'F' is not available
#app_id 5729517255058371973 'F' is not available
# Out:
#                     app_id gender  count
# 12736  8693964245073640147      M  32636
# 10343  5927333115845830913      M  25785
# 9353   4348659952760821294      M  25195
# 6991    628020936226491308      M  18994
# 8826   3433289601737013244      M  13974
# 11859  7348340405200054701      M  11191
# 12735  8693964245073640147      F  10559
# 10645  6284164581582112235      M   9654
# 2405  -5368809411346728624      M   9381
# 12899  8948670408023620661      M   9119
# 10219  5729517255058371973      M   9088

# %%
#add the missing appids and respective gender with count as 0
missing_appids = [pd.Series([5927333115845830913, 'F', 0],index=grouped.columns), 
                       pd.Series([4348659952760821294, 'F', 0],index=grouped.columns), 
                       pd.Series([628020936226491308, 'F', 0],index=grouped.columns), 
                       pd.Series([3433289601737013244, 'F', 0],index=grouped.columns), 
                       pd.Series([7348340405200054701, 'F', 0],index=grouped.columns), 
                       pd.Series([6284164581582112235, 'F', 0],index=grouped.columns), 
                       pd.Series([-5368809411346728624, 'F', 0],index=grouped.columns), 
                       pd.Series([8948670408023620661, 'F', 0],index=grouped.columns),
                       pd.Series([5729517255058371973, 'F', 0],index=grouped.columns)
                      ]
grouped = grouped.append(missing_appids, ignore_index=True)

# %%
grouped.sort_values(by=['app_id'])
# Out:
#                  app_id gender  count
# 17 -5368809411346728624      F      0
# 8  -5368809411346728624      M   9381
# 3    628020936226491308      M  18994
# 13   628020936226491308      F      0
# 4   3433289601737013244      M  13974
# 14  3433289601737013244      F      0
# 2   4348659952760821294      M  25195
# 12  4348659952760821294      F      0
# 19  5729517255058371973      F      0
# 10  5729517255058371973      M   9088
# 1   5927333115845830913      M  25785
# 11  5927333115845830913      F      0
# 7   6284164581582112235      M   9654
# 16  6284164581582112235      F      0
# 5   7348340405200054701      M  11191
# 15  7348340405200054701      F      0
# 0   8693964245073640147      M  32636
# 6   8693964245073640147      F  10559
# 18  8948670408023620661      F      0
# 9   8948670408023620661      M   9119

# %%
#now plot the chart
N = 10
ind = np.arange(N)    # the x locations for the groups
appid_list = grouped.app_id.unique().tolist()
g1 = np.array(grouped[grouped.gender == 'M']['count'].tolist())
g2 = np.array(grouped[grouped.gender == 'F']['count'].tolist())
#print('appid_list=',appid_list)
#print('g1=',g1)
#print('g2=',g2)
plt.figure(figsize=(9,7))
p1 = plt.bar(ind, g1, label='Male')
p2 = plt.bar(ind, g2, bottom=sum([g1]),label='Female')
plt.title('Top 10 Applications across Gender')
plt.xlabel('App Ids')
plt.ylabel('Count')
plt.xticks(ind, appid_list, rotation=90)
plt.legend()
plt.show()

# %%
import warnings
import numpy as np
warnings.simplefilter(action='ignore', category=FutureWarning)
dfapp.loc[dfapp['app_id']=='8693964245073640147']
# Out:
# Empty DataFrame
# Columns: [event_id, app_id, is_installed, is_active, label_id, category]
# Index: []

# %% [markdown]
# #### 4.10 Top 10  Mobile Phone Brand  by age groups [Consider the age groups as 0-24, 25-32, 33-45, 46+]

# %%
#feel the dataset before plotting.
dfsubset = dfnev[['age','phone_brand']]
age_bins = pd.cut(dfsubset['age'], bins=[0, 24, 33, 46,100],labels=['0-24','25-32','33-45','46+'])
grouped = dfsubset.groupby(['phone_brand', age_bins])['phone_brand'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(29)
grouped.sort_values(by=['phone_brand'])
#observation
#===========
#Coolpad - Age group '46+' is not available
#Gionee - Age group '0-24','33-45','46+' is not available
#HTC - Age group '0-24','33-45','46+' is not available
#Meizu - Age group '46+' is not available
#OPPO - Age group '46+' is not available
#lenovo - Age group '46+' is not available
#vivo - Age group '46+' is not available
# Out:
#     phone_brand    age  count
# 24      Coolpad   0-24    811
# 26      Coolpad  33-45    881
# 25      Coolpad  25-32   1324
# 37       Gionee  25-32    414
# 41          HTC  25-32    474
# 45       Huawei  25-32   5641
# 47       Huawei    46+   1235
# 46       Huawei  33-45   3676
# 44       Huawei   0-24   2449
# 86        Meizu  33-45    612
# 85        Meizu  25-32   2162
# 84        Meizu   0-24   1687
# 98         OPPO  33-45   1074
# 96         OPPO   0-24   1861
# 97         OPPO  25-32   2542
# 148      Xiaomi   0-24   4235
# 150      Xiaomi  33-45   3701
# 149      Xiaomi  25-32   8059
# 151      Xiaomi    46+   1342
# 265      lenovo  25-32   1083
# 266      lenovo  33-45    696
# 264      lenovo   0-24    614
# 347     samsung    46+   1364
# 344     samsung   0-24   2370
# 346     samsung  33-45   3831
# 345     samsung  25-32   6141
# 354        vivo  33-45    918
# 353        vivo  25-32   2473
# 352        vivo   0-24   1980

# %%
#Add the missing phone brands & age group into the dataframe with count 0
missing_phonebrands = [pd.Series(['Coolpad', '46+', 0],index=grouped.columns), 
                       pd.Series(['Gionee', '0-24', 0],index=grouped.columns), 
                       pd.Series(['Gionee', '33-45', 0],index=grouped.columns), 
                       pd.Series(['Gionee', '46+', 0],index=grouped.columns), 
                       pd.Series(['HTC', '0-24', 0],index=grouped.columns), 
                       pd.Series(['HTC', '33-45', 0],index=grouped.columns), 
                       pd.Series(['HTC', '46+', 0],index=grouped.columns), 
                       pd.Series(['Meizu', '46+', 0],index=grouped.columns), 
                       pd.Series(['OPPO', '46+', 0],index=grouped.columns), 
                       pd.Series(['lenovo', '46+', 0],index=grouped.columns), 
                       pd.Series(['vivo', '46+', 0],index=grouped.columns)                       
                      ]
grouped = grouped.append(missing_phonebrands, ignore_index=True)

# %%
grouped.sort_values(by=['phone_brand','count'], ascending=[True, False])
# Out:
#    phone_brand    age  count
# 17     Coolpad  25-32   1324
# 22     Coolpad  33-45    881
# 23     Coolpad   0-24    811
# 29     Coolpad    46+      0
# 28      Gionee  25-32    414
# 30      Gionee   0-24      0
# 31      Gionee  33-45      0
# 32      Gionee    46+      0
# 27         HTC  25-32    474
# 33         HTC   0-24      0
# 34         HTC  33-45      0
# 35         HTC    46+      0
# 2       Huawei  25-32   5641
# 6       Huawei  33-45   3676
# 9       Huawei   0-24   2449
# 18      Huawei    46+   1235
# 11       Meizu  25-32   2162
# 14       Meizu   0-24   1687
# 26       Meizu  33-45    612
# 36       Meizu    46+      0
# 7         OPPO  25-32   2542
# 13        OPPO   0-24   1861
# 20        OPPO  33-45   1074
# 37        OPPO    46+      0
# 0       Xiaomi  25-32   8059
# 3       Xiaomi   0-24   4235
# 5       Xiaomi  33-45   3701
# 16      Xiaomi    46+   1342
# 19      lenovo  25-32   1083
# 24      lenovo  33-45    696
# 25      lenovo   0-24    614
# 38      lenovo    46+      0
# 1      samsung  25-32   6141
# 4      samsung  33-45   3831
# 10     samsung   0-24   2370
# 15     samsung    46+   1364
# 8         vivo  25-32   2473
# 12        vivo   0-24   1980
# 21        vivo  33-45    918
# 39        vivo    46+      0

# %%
#now plot the chart
N = 10
ind = np.arange(N)    # the x locations for the groups
phone_list = grouped.phone_brand.unique().tolist()
g1 = np.array(grouped[grouped.age == '0-24']['count'].tolist())
g2 = np.array(grouped[grouped.age == '25-32']['count'].tolist())
g3 = np.array(grouped[grouped.age == '33-45']['count'].tolist())
g4 = np.array(grouped[grouped.age == '46+']['count'].tolist())

plt.figure(figsize=(10,8))
p1 = plt.bar(ind, g1, label='0-24')
p2 = plt.bar(ind, g2, bottom=sum([g1]),label='25-32')
p3 = plt.bar(ind, g3, bottom=sum([g1, g2]),label='33-45')
p4 = plt.bar(ind, g4, bottom=sum([g1, g2, g3]),label='46+')
plt.title('Top 10 mobile brands across age groups')
plt.xlabel('Phone Brand')
plt.ylabel('Count')
plt.xticks(ind, phone_list, rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### Export Event, Non-event and Appdata dataframe to csv, then upload to S3 bucket

# %%
#save non-event dataframe to csv
dfnev.to_csv(r'non_events_init.csv', index = False)

# %%
#save event dataframe to csv
dfev.to_csv(r'events_init.csv', index = False)

# %%
#save app dataframe to csv
dfapp.to_csv(r'appdata_init.csv', index = False)

# %%
#upload non_events csv to S3
# !aws s3 cp non_events_init.csv s3://capstone-sanjanameghna/final_submission/non_events_init.csv
# Out:
# upload: ./non_events_init.csv to s3://capstone-sanjanameghna/final_submission/non_events_init.csv

# %%
#upload events csv to S3
# !aws s3 cp events_init.csv s3://capstone-sanjanameghna/final_submission/events_init.csv
# Out:
# upload: ./events_init.csv to s3://capstone-sanjanameghna/final_submission/events_init.csv

# %%
#upload appdate csv to S3
# !aws s3 cp appdata_init.csv s3://capstone-sanjanameghna/final_submission/appdata_init.csv
# Out:
# upload: ./appdata_init.csv to s3://capstone-sanjanameghna/final_submission/appdata_init.csv
